# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/Copy_of_De_gentrificAItion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2016 Data Cleaning

# %%
import pandas as pd

# df = pd.read_csv('/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/Copy of 2016_montreal_data.csv')
df = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/2016_montreal_data.csv')

print(df)
print(len(df))
# Out:
# <ipython-input-2-b2072e70b137>:4: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/2016_montreal_data.csv')
#          CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL  GEO_NAME  GNR  GNR_LF  \
# 0               2016           462.0          1  Montréal  3.3     3.7
# 1               2016           462.0          1  Montréal  3.3     3.7
# 2               2016           462.0          1  Montréal  3.3     3.7
# 3               2016           462.0          1  Montréal  3.3     3.7
# 4               2016           462.0          1  Montréal  3.3     3.7
# ...              ...             ...        ...       ...  ...     ...
# 2179585         2016       4622401.0          2    2401.0  1.8     2.6
# 2179586         2016       4622401.0          2    2401.0  1.8     2.6
# 2179587         2016       4622401.0          2    2401.0  1.8     2.6
# 2179588         2016       4622402.0          2    2402.0  2.5     5.2
# 2179589         2016       4622402.0          2    2402.0  2.5     5.2
#
#          DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 0                    20000           462
# 1                    20000           462
# 2                    20000           462
# 3                    20000           462
# 4                    20000           462
# ...                    ...           ...
# 2179585                  0     462240100
# 2179586                  0     462240100
# 2179587                  0     462240100
# 2179588                  0     462240200
# 2179589                  0     462240200
#
#                   DIM: Profile of Census Tracts (2247)  \
# 0           Population percentage change, 2011 to 2016
# 1                              Total private dwellings
# 2        Private dwellings occupied by usual residents
# 3              Population density per square kilometre
# 4                       Land area in square kilometres
# ...                                                ...
# 2179585                       Intraprovincial migrants
# 2179586                       Interprovincial migrants
# 2179587                              External migrants
# 2179588                               Population, 2016
# 2179589                               Population, 2011
#
#          Member ID: Profile of Census Tracts (2247)  \
# 0                                                 3
# 1                                                 4
# 2                                                 5
# 3                                                 6
# 4                                                 7
# ...                                             ...
# 2179585                                        2245
# 2179586                                        2246
# 2179587                                        2247
# 2179588                                           1
# 2179589                                           2
#
#          Notes: Profile of Census Tracts (2247)  \
# 0                                           NaN
# 1                                           3.0
# 2                                           4.0
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2179585                                     NaN
# 2179586                                     NaN
# 2179587                                     NaN
# 2179588                                     1.0
# 2179589                                     2.0
#
#         Dim: Sex (3): Member ID: [1]: Total - Sex  \
# 0                                             4.2
# 1                                       1823281.0
# 2                                       1727310.0
# 3                                           890.2
# 4                                         4604.26
# ...                                           ...
# 2179585                                       380
# 2179586                                        35
# 2179587                                         0
# 2179588                                      3484
# 2179589                                      2685
#
#         Dim: Sex (3): Member ID: [2]: Male  \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
# ...                                    ...
# 2179585                                175
# 2179586                                 20
# 2179587                                  0
# 2179588                                ...
# 2179589                                ...
#
#         Dim: Sex (3): Member ID: [3]: Female
# 0                                        ...
# 1                                        ...
# 2                                        ...
# 3                                        ...
# 4                                        ...
# ...                                      ...
# 2179585                                  205
# 2179586                                   20
# 2179587                                    0
# 2179588                                  ...
# 2179589                                  ...
#
# [2179590 rows x 14 columns]
# 2179590

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Loop through questions and save the ones we want to keep

conditions = [
    'Population, 2016',
    'Population percentage change, 2011 to 2016',
    'Total private dwellings',
    'Private dwellings occupied by usual residents',
    'Population density per square kilometre',
    'Total - Age groups and average age of the population - 100% data',
    '0 to 14 years',
    '15 to 19 years',
    '20 to 24 years',
    '25 to 29 years',
    '30 to 34 years',
    '35 to 39 years',
    '40 to 44 years',
    '45 to 49 years',
    '50 to 54 years',
    '55 to 59 years',
    '60 to 64 years',
    '65 years and over',
    'Median age of the population',
    'Average age of the population',
    'Total - Occupied private dwellings by structural type of dwelling - 100% data',
    'Single-detached house',
    'Apartment in a building that has five or more storeys',
    'Semi-detached house',
    'Row house',
    'Apartment or flat in a duplex',
    'Apartment in a building that has fewer than five storeys',
    'Other single-attached house',
    'Movable dwelling',
    'Average household size',
    'Total - Marital status for the population aged 15 years and over - 100% data',
    'Married or living common law',
    'Not married and not living common law',
    'Total - Private households by household type - 100% data',
    'One-census-family households',
    'Multiple-census-family households',
    'Non-census-family households',
    'Median total income of households in 2015 ($)',
    'Median after-tax income of households in 2015 ($)',
    'Prevalence of low income based on the Low-income measure, after tax (LIM-AT) (%)',
    'Prevalence of low income based on the Low-income cut-offs, after tax (LICO-AT) (%)',
    'Total - Citizenship for the population in private households - 25% sample data',
    'Canadian citizens',
    'Not Canadian citizens',
    'Total - Immigrant status and period of immigration for the population in private households - 25% sample data',
    'Non-immigrants',
    'Immigrants',
    'Non-permanent residents',
    'Total - Visible minority for the population in private households - 25% sample data',
    'Total visible minority population',
    'Not a visible minority',
    'Total - Private households by tenure - 25% sample data',
    'Owner',
    'Renter',
    'Band housing',
    'Total - Occupied private dwellings by condominium status - 25% sample data',
    'Condominium',
    'Not condominium',
    'Total - Private households by housing suitability - 25% sample data',
    'Suitable',
    'Not suitable',
    'Total - Occupied private dwellings by dwelling condition - 25% sample data',
    'Only regular maintenance or minor repairs needed',
    'Major repairs needed',
    'Average number of rooms per dwelling',
    '% of tenant households in subsidized housing',
    'Median monthly shelter costs for owned dwellings ($)',
    'Average monthly shelter costs for owned dwellings ($)',
    'Median value of dwellings ($)',
    'Average value of dwellings ($)',
    'Median monthly shelter costs for rented dwellings ($)',
    'Median monthly shelter costs for rented dwellings ($)',
    'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data',
    'No certificate, diploma or degree',
    'Secondary (high) school diploma or equivalency certificate',
    'Postsecondary certificate, diploma or degree',
    'College, CEGEP or other non-university certificate or diploma',
    'University certificate or diploma below bachelor level',
    'University certificate, diploma or degree at bachelor level or above',
    'Total - Location of study compared with province or territory of residence with countries outside Canada for the population aged 15 years and over in private households - 25% sample data',
    'Location of study inside Canada',
    'Same as province or territory of residence',
    'Different than province or territory of residence',
    'Location of study outside Canada',
    'Total - Population aged 15 years and over by Labour force status - 25% sample data',
    'In the labour force',
    'Not in the labour force',
    'Total - Main mode of commuting for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data',
    'Car, truck, van - as a driver',
    'Car, truck, van - as a passenger',
    'Public transit',
    'Walked',
    'Bicycle',
    'Other method',
    'Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data',
    'Less than 15 minutes',
    '15 to 29 minutes',
    '30 to 44 minutes',
    '45 to 59 minutes',
    '60 minutes and over',
    'Total - Mobility status 1 year ago - 25% sample data',
    'Non-movers',
    'Movers'
]

# Filtering the DataFrame to get rows that match the conditions
new_df = df.loc[df['DIM: Profile of Census Tracts (2247)'].isin(conditions)]

print(new_df)
# Out:
#          CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL  GEO_NAME  GNR  GNR_LF  \
# 0               2016           462.0          1  Montréal  3.3     3.7
# 1               2016           462.0          1  Montréal  3.3     3.7
# 2               2016           462.0          1  Montréal  3.3     3.7
# 3               2016           462.0          1  Montréal  3.3     3.7
# 5               2016           462.0          1  Montréal  3.3     3.7
# ...              ...             ...        ...       ...  ...     ...
# 2179571         2016       4622401.0          2    2401.0  1.8     2.6
# 2179572         2016       4622401.0          2    2401.0  1.8     2.6
# 2179580         2016       4622401.0          2    2401.0  1.8     2.6
# 2179581         2016       4622401.0          2    2401.0  1.8     2.6
# 2179588         2016       4622402.0          2    2402.0  2.5     5.2
#
#          DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 0                    20000           462
# 1                    20000           462
# 2                    20000           462
# 3                    20000           462
# 5                    20000           462
# ...                    ...           ...
# 2179571                  0     462240100
# 2179572                  0     462240100
# 2179580                  0     462240100
# 2179581                  0     462240100
# 2179588                  0     462240200
#
#                       DIM: Profile of Census Tracts (2247)  \
# 0               Population percentage change, 2011 to 2016
# 1                                  Total private dwellings
# 2            Private dwellings occupied by usual residents
# 3                  Population density per square kilometre
# 5        Total - Age groups and average age of the popu...
# ...                                                    ...
# 2179571                                         Non-movers
# 2179572                                             Movers
# 2179580                                         Non-movers
# 2179581                                             Movers
# 2179588                                   Population, 2016
#
#          Member ID: Profile of Census Tracts (2247)  \
# 0                                                 3
# 1                                                 4
# 2                                                 5
# 3                                                 6
# 5                                                 8
# ...                                             ...
# 2179571                                        2231
# 2179572                                        2232
# 2179580                                        2240
# 2179581                                        2241
# 2179588                                           1
#
#          Notes: Profile of Census Tracts (2247)  \
# 0                                           NaN
# 1                                           3.0
# 2                                           4.0
# 3                                           NaN
# 5                                           5.0
# ...                                         ...
# 2179571                                     NaN
# 2179572                                     NaN
# 2179580                                     NaN
# 2179581                                     NaN
# 2179588                                     1.0
#
#         Dim: Sex (3): Member ID: [1]: Total - Sex  \
# 0                                             4.2
# 1                                       1823281.0
# 2                                       1727310.0
# 3                                           890.2
# 5                                       4098930.0
# ...                                           ...
# 2179571                                      3350
# 2179572                                       290
# 2179580                                      2355
# 2179581                                      1080
# 2179588                                      3484
#
#         Dim: Sex (3): Member ID: [2]: Male  \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 5                                  2000935
# ...                                    ...
# 2179571                               1685
# 2179572                                140
# 2179580                               1235
# 2179581                                505
# 2179588                                ...
#
#         Dim: Sex (3): Member ID: [3]: Female
# 0                                        ...
# 1                                        ...
# 2                                        ...
# 3                                        ...
# 5                                    2097990
# ...                                      ...
# 2179571                                 1665
# 2179572                                  150
# 2179580                                 1120
# 2179581                                  575
# 2179588                                  ...
#
# [117370 rows x 14 columns]

# %%
# drop gender columns

new_df = new_df.drop('Dim: Sex (3): Member ID: [2]: Male', axis=1)
new_df = new_df.drop('Dim: Sex (3): Member ID: [3]: Female', axis=1)
new_df = new_df.drop('Notes: Profile of Census Tracts (2247)', axis=1)
new_df = new_df.drop('Member ID: Profile of Census Tracts (2247)', axis=1)
new_df = new_df.drop('GEO_LEVEL', axis=1)
# new_df = new_df.drop('GEO_CODE (POR)', axis=1)
new_df = new_df.drop('GNR', axis=1)
new_df = new_df.drop('GNR_LF', axis=1)
new_df = new_df.drop('DATA_QUALITY_FLAG', axis=1)
new_df = new_df.drop('ALT_GEO_CODE', axis=1)


print(new_df.head())
# Out:
#    CENSUS_YEAR  GEO_CODE (POR)  GEO_NAME  \
# 0         2016           462.0  Montréal
# 1         2016           462.0  Montréal
# 2         2016           462.0  Montréal
# 3         2016           462.0  Montréal
# 5         2016           462.0  Montréal
#
#                 DIM: Profile of Census Tracts (2247)  \
# 0         Population percentage change, 2011 to 2016
# 1                            Total private dwellings
# 2      Private dwellings occupied by usual residents
# 3            Population density per square kilometre
# 5  Total - Age groups and average age of the popu...
#
#   Dim: Sex (3): Member ID: [1]: Total - Sex
# 0                                       4.2
# 1                                 1823281.0
# 2                                 1727310.0
# 3                                     890.2
# 5                                 4098930.0

# %%
print(len(new_df))
# Out:
# 117370

# %%
# loop over rows, make a dict
# items = {'region':{}}
items = {}
for i in range(len(new_df)):
  # if i > 10:
  #   break
  # print(new_df.iloc[i]['GEO_NAME'])
  outer_key = new_df.iloc[i]['GEO_NAME']
  if outer_key in items:
    inner_key = new_df.iloc[i]['DIM: Profile of Census Tracts (2247)'] + ' 2016'
    items[outer_key][inner_key] = new_df.iloc[i]['Dim: Sex (3): Member ID: [1]: Total - Sex']
  else:
    items[outer_key] = {'ctuid': new_df.iloc[i]['GEO_CODE (POR)']}
    inner_key = new_df.iloc[i]['DIM: Profile of Census Tracts (2247)'] + ' 2016'
    items[outer_key][inner_key] = new_df.iloc[i]['Dim: Sex (3): Member ID: [1]: Total - Sex']
print(items.keys())
# Out:
# dict_keys(['Montréal', '0001.00', '0002.00', '0003.00', '0004.00', '0005.00', '0006.00', '0007.00', '0008.00', '0009.00', '0010.00', '0011.00', '0012.01', '0012.02', '0013.00', '0014.01', '14.01', '14.02', '15.0', '16.0', '17.0', '18.0', '19.0', '21.0', '22.0', '23.0', '24.0', '25.0', '26.0', '27.0', '28.0', 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.01, 55.02, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.01, 65.02, 66.01, 66.02, 67.0, 68.0, 69.01, 69.02, 70.01, 70.02, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.01, 94.02, 95.0, 96.0, 97.01, 97.02, 98.0, 99.0, 100.01, 100.02, 101.01, 101.02, 102.0, 103.0, 104.0, 105.0, 106.0, 107.0, 108.0, 109.0, 110.0, 111.0, 112.01, 112.02, 113.0, 114.0, 115.01, 115.02, 116.0, 117.0, 118.0, 119.0, 120.01, 120.02, 121.0, 122.0, 123.0, 124.0, 125.0, 126.0, 127.01, 127.02, 128.0, 129.01, 129.02, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0, 145.0, 146.0, 147.0, 148.0, 149.0, 150.0, 151.0, 152.0, 153.0, 154.0, 155.0, 156.0, 157.0, 158.0, 159.0, 160.0, 161.0, 162.0, 163.0, 164.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 171.0, 172.0, 173.0, 174.0, 175.0, 176.0, 177.0, 178.0, 179.0, 180.0, 181.0, 182.0, 183.0, 184.0, 185.0, 186.0, 187.01, 187.03, 187.04, 188.01, 188.02, 189.0, 190.01, 190.02, 191.0, 192.0, 193.0, 194.0, 195.01, 195.02, 195.03, 196.0, 197.0, 198.0, 199.0, 200.0, 201.0, 202.0, 203.0, 204.0, 205.0, 206.0, 207.0, 208.0, 209.0, 210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0, 219.0, 220.0, 221.0, 222.0, 223.01, 223.02, 224.0, 225.0, 226.0, 227.0, 228.0, 229.0, 230.0, 231.0, 232.0, 233.0, 234.0, 235.0, 236.0, 237.0, 238.0, 239.0, 240.0, 241.0, 242.0, 243.0, 244.0, 245.0, 247.0, 249.0, 250.0, 251.01, 251.02, 252.0, 253.0, 254.0, 256.0, 257.0, 258.0, 259.0, 260.0, 261.0, 262.0, 263.0, 264.01, 264.02, 265.0, 266.0, 267.0, 268.01, 268.02, 268.03, 269.0, 270.0, 271.0, 272.0, 273.0, 274.0, 275.0, 276.0, 277.0, 278.0, 279.0, 280.0, 281.0, 282.0, 283.01, 283.02, 284.0, 285.0, 286.0, 287.01, 287.02, 288.0, 290.01, 290.02, 290.03, 290.04, 290.05, 290.06, 290.07, 290.08, 290.09, 291.01, 291.03, 291.04, 300.0, 301.0, 302.0, 303.0, 304.0, 305.0, 306.0, 307.0, 308.0, 309.0, 310.0, 311.0, 312.0, 313.0, 314.0, 315.0, 316.0, 317.02, 317.03, 317.04, 320.0, 321.0, 322.02, 322.03, 322.04, 323.0, 324.01, 324.02, 325.01, 325.02, 325.03, 325.05, 325.06, 326.01, 326.02, 326.03, 327.0, 328.0, 329.0, 330.0, 340.0, 350.0, 351.0, 352.0, 353.0, 354.0, 355.0, 356.0, 360.0, 361.0, 362.0, 363.0, 364.0, 365.0, 366.0, 367.0, 370.0, 380.0, 381.0, 382.01, 382.02, 383.01, 383.02, 385.0, 390.0, 391.0, 392.0, 393.0, 394.0, 395.01, 395.02, 395.03, 396.0, 397.0, 400.0, 401.0, 402.0, 403.0, 404.0, 410.01, 410.02, 410.03, 412.0, 413.01, 413.02, 415.03, 415.04, 415.05, 415.06, 416.01, 416.02, 417.01, 417.02, 418.0, 419.0, 420.0, 421.01, 421.02, 430.0, 431.0, 432.0, 433.0, 440.0, 450.0, 451.0, 452.0, 453.01, 453.02, 460.0, 461.0, 462.01, 462.02, 470.01, 470.03, 470.04, 470.05, 480.0, 490.0, 491.0, 500.0, 511.01, 511.02, 512.02, 512.03, 512.04, 513.01, 513.02, 514.01, 514.02, 515.01, 515.02, 515.03, 515.04, 520.02, 520.03, 520.04, 521.01, 521.04, 521.05, 521.06, 521.07, 522.01, 522.02, 523.0, 530.0, 540.0, 550.02, 550.03, 550.04, 570.0, 580.01, 580.02, 580.03, 581.01, 581.02, 582.01, 582.02, 583.0, 584.0, 585.01, 585.02, 590.01, 590.02, 591.01, 591.02, 592.0, 593.01, 593.02, 594.01, 594.02, 600.01, 600.02, 600.03, 601.01, 601.02, 602.01, 602.02, 603.01, 603.02, 603.03, 604.01, 604.02, 604.03, 604.04, 604.05, 605.01, 605.02, 605.03, 605.04, 605.05, 610.01, 610.02, 610.03, 610.04, 610.05, 610.06, 610.07, 611.01, 611.02, 612.0, 613.0, 614.0, 615.0, 616.0, 617.01, 617.02, 618.0, 619.0, 625.01, 625.02, 626.0, 627.0, 628.01, 628.02, 629.0 ...

# %%
# Check if a specific condition is an inner key of a specific GEO location

specific_outer_key = "Montréal"
specific_inner_key = "Population, 2016 2016"

if specific_outer_key in items:
    if specific_inner_key in items[specific_outer_key]:
        print(f'Item with outer key "{specific_outer_key}" and inner key "{specific_inner_key}" is in the dictionary.')
    else:
        print(f'Inner key "{specific_inner_key}" is not in the dictionary for outer key "{specific_outer_key}".')
else:
    print(f'Outer key "{specific_outer_key}" is not in the dictionary.')
# Out:
# Inner key "Population, 2016 2016" is not in the dictionary for outer key "Montréal".

# %%
# Convert the dictionary of dictionaries into a DataFrame
df = pd.DataFrame.from_dict(items, orient='index')

# Write the DataFrame to a CSV file
# df.to_csv('/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/2016_output.csv')
df.to_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/2016_emilie_v1.csv')

print(df)
print(df.columns)
# Out:
#               ctuid Population percentage change, 2011 to 2016 2016  \
# Montréal      462.0                                             4.2
# 0001.00   4620001.0                                             1.2
# 0002.00   4620002.0                                            15.7
# 0003.00   4620003.0                                             2.2
# 0004.00   4620004.0                                            -2.6
# ...             ...                                             ...
# 2303.0    4622303.0                                             ...
# 2304.0    4622304.0                                            -1.1
# 2400.0    4622400.0                                            -2.5
# 2401.0    4622401.0                                            11.4
# 2402.0    4622402.0                                             NaN
#
#          Total private dwellings 2016  \
# Montréal                    1823281.0
# 0001.00                        1452.0
# 0002.00                        1902.0
# 0003.00                        3103.0
# 0004.00                        1704.0
# ...                               ...
# 2303.0                              0
# 2304.0                            445
# 2400.0                           1180
# 2401.0                           1400
# 2402.0                            NaN
#
#          Private dwellings occupied by usual residents 2016  \
# Montréal                                          1727310.0
# 0001.00                                              1328.0
# 0002.00                                              1762.0
# 0003.00                                              2937.0
# 0004.00                                              1603.0
# ...                                                     ...
# 2303.0                                                    0
# 2304.0                                                  443
# 2400.0                                                 1132
# 2401.0                                                 1381
# 2402.0                                                  NaN
#
#          Population density per square kilometre 2016  \
# Montréal                                        890.2
# 0001.00                                        5710.0
# 0002.00                                        9029.3
# 0003.00                                        8612.2
# 0004.00                                        7087.7
# ...                                               ...
# 2303.0                                            0.0
# 2304.0                                         1557.5
# 2400.0                                           58.8
# 2401.0                                          837.5
# 2402.0                                            NaN
#
#          Total - Age groups and average age of the population - 100% data 2016  \
# Montréal                                          4098930.0
# 0001.00                                              2635.0
# 0002.00                                              3515.0
# 0003.00                                              6375.0
# 0004.00                                              3175.0
# ...                                                     ...
# 2303.0                                                    x
# 2304.0                                                 1095
# 2400.0                                                 2730
# 2401.0                                                 3690
# 2402.0                                                  NaN
#
#          0 to 14 years 2016 15 to 19 years 2016 20 to 24 years 2016  \
# Montréal               16.9            225350.0            271640.0
# 0001.00                12.5               120.0               160.0
# 0002.00                15.6               145.0               230.0
# 0003.00                15.5               305.0               350.0
# 0004.00                12.1               145.0               205.0
# ...                     ...                 ...                 ...
# 2303.0                    x                   x                   x
# 2304.0                 15.1                  70                  60
# 2400.0                 15.9                 135                 150
# 2401.0                 21.4                 215                 175
# 2402.0                  NaN                 NaN                 NaN
#
#          25 to 29 years 2016  ...  \
# Montréal            270735.0  ...
# 0001.00                200.0  ...
# 0002.00                255.0  ...
# 0003.00                430.0  ...
# 0004.00                220.0  ...
# ...                      ...  ...
# 2303.0                     x  ...
# 2304.0                    40  ...
# 2400.0                   145  ...
# 2401.0                   230  ...
# 2402.0                   NaN  ...
#
#          Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data 2016  \
# Montréal                                          1883815.0
# 0001.00                                              1375.0
# 0002.00                                              1650.0
# 0003.00                                              2810.0
# 0004.00                                              1585.0
# ...                                                     ...
# 2303.0                                                    x
# 2304.0                                                  570
# 2400.0                                                 1205
# 2401.0                                                 1880
# 2402.0                                                  NaN
#
#          Less than 15 minutes 2016 15 to 29 minutes 2016  \
# Montréal                  341880.0              601245.0
# 0001.00                      220.0                 415.0
# 0002.00                      255.0                 525.0
# 0003.00                      385.0                 885.0
# 0004.00                      270.0                 455.0
# ...                            ...                   ...
# 2303.0                           x                     x
# 2304.0                         260                   110
# 2400.0                         385                   355
# 2401.0                         610                   575
# 2402.0                         NaN                   NaN
#
#          30 to 44 minutes 2016 45 to 59 minutes 2016 60 minutes and over 2016  \
# Montréal              489215.0              235365.0                 216115.0
# 0001.00                  350.0                 200.0                    195.0
# 0002.00                  375.0                 280.0                    220.0
# 0003.00                  780.0                 410.0                    360.0
# 0004.00                  425.0                 275.0                    155.0
# ...                        ...                   ...                      ...
# 2303.0                       x                     x                        x
# 2304.0                      95                    45                       60
# 2400.0                     235                   130                       95
# 2401.0                     325                   215                      160
# 2402.0                     NaN                   NaN                      NaN
#
#          Total - Mobility status 1 year ago - 25% sample data 2016  \
# Montréal                                          3965040.0
# 0001.00                                              2670.0
# 0002.00                                              3305.0
# 0003.00                                              6195.0
# 0004.00                                              3110.0
# ...                                                     ...
# 2303.0                                                    x
# 2304.0                                                 1085
# 2400.0                                                 2700
# 2401.0                                                 3640
# 2402.0                                                  NaN
#
#          Non-movers 2016 Movers 2016 Population, 2016 2016
# Montréal       2325075.0   1453460.0                   NaN
# 0001.00           1470.0      1075.0                2638.0
# 0002.00           1345.0      1780.0                3516.0
# 0003.00           3485.0      2440.0                6373.0
# 0004.00           1760.0      1230.0                3176.0
# ...                  ...         ...                   ...
# 2303.0                 x           x                     0
# 2304.0               790         260                  1094
# 2400.0              1890         680                  2729
# 2401.0              2355        1080                  3691
# 2402.0               NaN         NaN                  3484
#
# [973 rows x 103 columns]
# Index(['ctuid', 'Population percentage change, 2011 to 2016 2016',
#        'Total private dwellings 2016',
#        'Private dwellings occupied by usual residents 2016',
#        'Population density per square kilometre 2016',
#        'Total - Age groups and average age of the population - 100% data 2016',
#        '0 to 14 years 2016', '15 to 19 years 2016', '20 to 24 years 2016',
#        '25 to 29 years 2016',
#        ...
#        'Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data 2016',
#        'Less than 15 minutes 2016', '15 to 29 minutes 2016',
#        '30 to 44 minutes 2016', '45 to 59 minutes 2016',
#        '60 minutes and over 2016',
#        'Total - Mobility status 1 year ago - 25% sample data 2016',
#        'Non-movers 2016', 'Movers 2016', 'Population, 2016 2016'],
#       dtype='object', length=103)

# %%
# check if a specific column exists in the cleaned df

if "Movers 2016" in df.columns:
    print('"Population, 2016" is in the column.')
else:
    print('"Population, 2016" is not in the column.')
# Out:
# "Population, 2016" is in the column.

# %% [markdown]
# # 2021 Data Cleaning

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/Copy of 2021_montreal_data.csv')

print(df)
print(len(df))
# Out:
# <ipython-input-57-e6fe6660bd1f>:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/Copy of 2021_montreal_data.csv')
#          CENSUS_YEAR                DGUID  ALT_GEO_CODE  \
# 0               2021         2021S0503462         462.0
# 1               2021         2021S0503462         462.0
# 2               2021         2021S0503462         462.0
# 3               2021         2021S0503462         462.0
# 4               2021         2021S0503462         462.0
# ...              ...                  ...           ...
# 2641519         2021  2021S05074622401.00     4622401.0
# 2641520         2021  2021S05074622401.00     4622401.0
# 2641521         2021  2021S05074622401.00     4622401.0
# 2641522         2021  2021S05074622402.00     4622402.0
# 2641523         2021  2021S05074622402.00     4622402.0
#
#                         GEO_LEVEL   GEO_NAME  TNR_SF  TNR_LF  \
# 0        Census metropolitan area   Montréal     2.6     3.4
# 1        Census metropolitan area   Montréal     2.6     3.4
# 2        Census metropolitan area   Montréal     2.6     3.4
# 3        Census metropolitan area   Montréal     2.6     3.4
# 4        Census metropolitan area   Montréal     2.6     3.4
# ...                           ...        ...     ...     ...
# 2641519              Census tract  4622401.0     1.2     1.8
# 2641520              Census tract  4622401.0     1.2     1.8
# 2641521              Census tract  4622401.0     1.2     1.8
# 2641522              Census tract  4622402.0     0.9     1.5
# 2641523              Census tract  4622402.0     0.9     1.5
#
#          DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 0                    20000                  3
# 1                    20000                  4
# 2                    20000                  5
# 3                    20000                  6
# 4                    20000                  7
# ...                    ...                ...
# 2641519                  0               2629
# 2641520                  0               2630
# 2641521                  0               2631
# 2641522                  0                  1
# 2641523                  0                  2
#
#                                        CHARACTERISTIC_NAME  ...  \
# 0               Population percentage change, 2016 to 2021  ...
# 1                                  Total private dwellings  ...
# 2            Private dwellings occupied by usual residents  ...
# 3                  Population density per square kilometre  ...
# 4                           Land area in square kilometres  ...
# ...                                                    ...  ...
# 2641519      Eligible children who have been instructed...  ...
# 2641520      Eligible children who have not been instru...  ...
# 2641521    Children not eligible for instruction in the...  ...
# 2641522                                   Population, 2021  ...
# 2641523                                   Population, 2016  ...
#
#          C2_COUNT_MEN+  SYMBOL.1 C3_COUNT_WOMEN+  SYMBOL.2 C10_RATE_TOTAL  \
# 0                  NaN       ...             NaN       ...            4.6
# 1                  NaN       ...             NaN       ...            NaN
# 2                  NaN       ...             NaN       ...            NaN
# 3                  NaN       ...             NaN       ...          919.0
# 4                  NaN       ...             NaN       ...            NaN
# ...                ...       ...             ...       ...            ...
# 2641519           25.0       NaN            20.0       NaN            6.8
# 2641520            5.0       NaN            10.0       NaN            2.0
# 2641521          330.0       NaN           340.0       NaN           91.8
# 2641522            NaN       ...             NaN       ...            NaN
# 2641523            NaN       ...             NaN       ...            NaN
#
#          SYMBOL.3 C11_RATE_MEN+  SYMBOL.4 C12_RATE_WOMEN+  SYMBOL.5
# 0             NaN           NaN       ...             NaN       ...
# 1             ...           NaN       ...             NaN       ...
# 2             ...           NaN       ...             NaN       ...
# 3             NaN           NaN       ...             NaN       ...
# 4             ...           NaN       ...             NaN       ...
# ...           ...           ...       ...             ...       ...
# 2641519       NaN           6.8       NaN             5.4       NaN
# 2641520       NaN           1.4       NaN             2.7       NaN
# 2641521       NaN          90.4       NaN            91.9       NaN
# 2641522       ...           NaN       ...             NaN       ...
# 2641523       ...           NaN       ...             NaN       ...
#
# [2641524 rows x 23 columns]
# 2641524

# %%
# Loop through questions and save the ones we want to keep

conditions = ['Population percentage change, 2011 to 2016',
              'Total private dwellings',
              'Private dwellings occupied by usual residents',
              'Population density per square kilometre',
              'Median total income in 2015 among recipients ($)',
              'Average household size', 'Non-immigrants', 'Immigrants',
              'Total visible minority population', 'Owner', 'Renter',
              'Band housing', 'Condominium', 'Not condominium',
              'Average number of rooms per dwelling', 'Suitable', 'Not suitable',
              'Only regular maintenance or minor repairs needed',
              'Major repairs needed',
              'Average monthly shelter costs for owned dwellings ($)',
              'Average value of dwellings ($)',
              '% of tenant households in subsidized housing',
              'Average monthly shelter costs for rented dwellings ($)',
              'In the labour force', 'Employed', 'Unemployed']

new_df = df.loc[df['CHARACTERISTIC_NAME'].isin(conditions)]

print(new_df)
# Out:
#          CENSUS_YEAR                DGUID  ALT_GEO_CODE  \
# 1               2021         2021S0503462         462.0
# 2               2021         2021S0503462         462.0
# 3               2021         2021S0503462         462.0
# 54              2021         2021S0503462         462.0
# 1430            2021         2021S0503462         462.0
# ...              ...                  ...           ...
# 2638894         2021  2021S05074622401.00     4622401.0
# 2638895         2021  2021S05074622401.00     4622401.0
# 2638896         2021  2021S05074622401.00     4622401.0
# 2638947         2021  2021S05074622401.00     4622401.0
# 2640323         2021  2021S05074622401.00     4622401.0
#
#                         GEO_LEVEL   GEO_NAME  TNR_SF  TNR_LF  \
# 1        Census metropolitan area   Montréal     2.6     3.4
# 2        Census metropolitan area   Montréal     2.6     3.4
# 3        Census metropolitan area   Montréal     2.6     3.4
# 54       Census metropolitan area   Montréal     2.6     3.4
# 1430     Census metropolitan area   Montréal     2.6     3.4
# ...                           ...        ...     ...     ...
# 2638894              Census tract  4622401.0     1.2     1.8
# 2638895              Census tract  4622401.0     1.2     1.8
# 2638896              Census tract  4622401.0     1.2     1.8
# 2638947              Census tract  4622401.0     1.2     1.8
# 2640323              Census tract  4622401.0     1.2     1.8
#
#          DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 1                    20000                  4
# 2                    20000                  5
# 3                    20000                  6
# 54                   20000                 57
# 1430                 20000               1433
# ...                    ...                ...
# 2638894                  0                  4
# 2638895                  0                  5
# 2638896                  0                  6
# 2638947                  0                 57
# 2640323                  0               1433
#
#                                    CHARACTERISTIC_NAME  ...  C2_COUNT_MEN+  \
# 1                              Total private dwellings  ...            NaN
# 2        Private dwellings occupied by usual residents  ...            NaN
# 3              Population density per square kilometre  ...            NaN
# 54                              Average household size  ...            NaN
# 1430              Average number of rooms per dwelling  ...            NaN
# ...                                                ...  ...            ...
# 2638894                        Total private dwellings  ...            NaN
# 2638895  Private dwellings occupied by usual residents  ...            NaN
# 2638896        Population density per square kilometre  ...            NaN
# 2638947                         Average household size  ...            NaN
# 2640323           Average number of rooms per dwelling  ...            NaN
#
#          SYMBOL.1 C3_COUNT_WOMEN+  SYMBOL.2 C10_RATE_TOTAL  SYMBOL.3  \
# 1             ...             NaN       ...            NaN       ...
# 2             ...             NaN       ...            NaN       ...
# 3             ...             NaN       ...          919.0       NaN
# 54            ...             NaN       ...            2.3       NaN
# 1430          ...             NaN       ...            5.5       NaN
# ...           ...             ...       ...            ...       ...
# 2638894       ...             NaN       ...            NaN       ...
# 2638895       ...             NaN       ...            NaN       ...
# 2638896       ...             NaN       ...          925.4       NaN
# 2638947       ...             NaN       ...            2.7       NaN
# 2640323       ...             NaN       ...            7.0       NaN
#
#         C11_RATE_MEN+  SYMBOL.4 C12_RATE_WOMEN+  SYMBOL.5
# 1                 NaN       ...             NaN       ...
# 2                 NaN       ...             NaN       ...
# 3                 NaN       ...             NaN       ...
# 54                NaN       ...             NaN       ...
# 1430              NaN       ...             NaN       ...
# ...               ...       ...             ...       ...
# 2638894           NaN       ...             NaN       ...
# 2638895           NaN       ...             NaN       ...
# 2638896           NaN       ...             NaN       ...
# 2638947           NaN       ...             NaN       ...
# 2640323           NaN       ...             NaN       ...
#
# [5020 rows x 23 columns]

# %%
print(len(new_df))
# Out:
# 5020

# %%
# drop unecessary columns

new_df = new_df.drop('DGUID', axis=1)
# new_df = new_df.drop('ALT_GEO_CODE', axis=1)
new_df = new_df.drop('GEO_LEVEL', axis=1)
new_df = new_df.drop('TNR_SF', axis=1)
new_df = new_df.drop('TNR_LF', axis=1)
new_df = new_df.drop('DATA_QUALITY_FLAG', axis=1)
new_df = new_df.drop('CHARACTERISTIC_ID', axis=1)
new_df = new_df.drop('CHARACTERISTIC_NOTE', axis=1)
new_df = new_df.drop('SYMBOL', axis=1)
new_df = new_df.drop('C2_COUNT_MEN+', axis=1)
new_df = new_df.drop('SYMBOL.1', axis=1)
new_df = new_df.drop('C3_COUNT_WOMEN+', axis=1)
new_df = new_df.drop('SYMBOL.2', axis=1)
new_df = new_df.drop('C10_RATE_TOTAL', axis=1)
new_df = new_df.drop('SYMBOL.3', axis=1)
new_df = new_df.drop('C11_RATE_MEN+', axis=1)
new_df = new_df.drop('SYMBOL.4', axis=1)
new_df = new_df.drop('C12_RATE_WOMEN+', axis=1)
new_df = new_df.drop('SYMBOL.5', axis=1)

print(new_df.head())
# Out:
#       CENSUS_YEAR  ALT_GEO_CODE  GEO_NAME  \
# 1            2021         462.0  Montréal
# 2            2021         462.0  Montréal
# 3            2021         462.0  Montréal
# 54           2021         462.0  Montréal
# 1430         2021         462.0  Montréal
#
#                                 CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 1                           Total private dwellings       1929263.0
# 2     Private dwellings occupied by usual residents       1835698.0
# 3           Population density per square kilometre           919.0
# 54                           Average household size             2.3
# 1430           Average number of rooms per dwelling             5.5

# %%
# loop over rows, make a dict

items = {}
for i in range(len(new_df)):
  outer_key = new_df.iloc[i]['GEO_NAME']
  if outer_key in items:
    inner_key = new_df.iloc[i]['CHARACTERISTIC_NAME'] + ' 2021'
    items[outer_key][inner_key] = new_df.iloc[i]['C1_COUNT_TOTAL']
  else:
    items[outer_key] = {}
print(items)
# Out:
# {'Montréal': {'Private dwellings occupied by usual residents 2021': 1835698.0, 'Population density per square kilometre 2021': 919.0, 'Average household size 2021': 2.3, 'Average number of rooms per dwelling 2021': 5.5}, '4620001.00': {'Private dwellings occupied by usual residents 2021': 1402.0, 'Population density per square kilometre 2021': 5780.7, 'Average household size 2021': 1.9, 'Average number of rooms per dwelling 2021': 4.6}, '4620002.00': {'Private dwellings occupied by usual residents 2021': 1944.0, 'Population density per square kilometre 2021': 9797.8, 'Average household size 2021': 1.9, 'Average number of rooms per dwelling 2021': 4.4}, '4620003.0': {'Private dwellings occupied by usual residents 2021': 3016.0, 'Population density per square kilometre 2021': 8917.7, 'Average household size 2021': 2.2, 'Average number of rooms per dwelling 2021': 5.0}, '4620004
# 4622401.0                                         7.0
#
# [1004 rows x 4 columns]

# %% [markdown]
# # 2011 Data Cleaning

# %% [markdown]
# # 2001 Data Cleaning

# %% [markdown]
# # 1996 Data Cleaning

# %% [markdown]
# # Standardizing Census Tracts
# do pop_dwe for dwelling

# %%
# example of apportioning data from source tracts to target tracts using an apportionment (i.e. crosswalk) table
import numpy as np
# the apportionment table
# crosswalk_csv = '/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/ct_2016_2021.csv'
crosswalk_csv = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/ct_2016_2021.csv'

# the csv with source tract data to apportioned
data_csv = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/2016_emilie_v1.csv'


# the name of the field pertaining to the ctuid in data_csv
ctuidcol = "ctuid"

# names of columns we want to apportion
fields = [
    'Population, 2016',
    #'Population percentage change, 2011 to 2016',
    'Total private dwellings',
    'Private dwellings occupied by usual residents',
    'Population density per square kilometre',
    'Total - Age groups and average age of the population - 100% data',
    '0 to 14 years',
    '15 to 19 years',
    '20 to 24 years',
    '25 to 29 years',
    '30 to 34 years',
    '35 to 39 years',
    '40 to 44 years',
    '45 to 49 years',
    '50 to 54 years',
    '55 to 59 years',
    '60 to 64 years',
    '65 years and over',
    'Median age of the population',
    'Average age of the population',
    'Total - Occupied private dwellings by structural type of dwelling - 100% data',
    'Single-detached house',
    'Apartment in a building that has five or more storeys',
    'Semi-detached house',
    'Row house',
    'Apartment or flat in a duplex',
    'Apartment in a building that has fewer than five storeys',
    'Other single-attached house',
    'Movable dwelling',
    'Average household size',
    'Total - Marital status for the population aged 15 years and over - 100% data',
    'Married or living common law',
    'Not married and not living common law',
    'Total - Private households by household type - 100% data',
    'One-census-family households',
    'Multiple-census-family households',
    'Non-census-family households',
    'Median total income of households in 2015 ($)',
    'Median after-tax income of households in 2015 ($)',
    'Prevalence of low income based on the Low-income measure, after tax (LIM-AT) (%)',
    'Prevalence of low income based on the Low-income cut-offs, after tax (LICO-AT) (%)',
    'Total - Citizenship for the population in private households - 25% sample data',
    'Canadian citizens',
    'Not Canadian citizens',
    'Total - Immigrant status and period of immigration for the population in private households - 25% sample data',
    'Non-immigrants',
    'Immigrants',
    'Non-permanent residents',
    'Total - Visible minority for the population in private households - 25% sample data',
    'Total visible minority population',
    'Not a visible minority',
    'Total - Private households by tenure - 25% sample data',
    'Owner',
    'Renter',
    'Band housing',
    'Total - Occupied private dwellings by condominium status - 25% sample data',
    'Condominium',
    'Not condominium',
    'Total - Private households by housing suitability - 25% sample data',
    'Suitable',
    'Not suitable',
    'Total - Occupied private dwellings by dwelling condition - 25% sample data',
    'Only regular maintenance or minor repairs needed',
    'Major repairs needed',
    'Average number of rooms per dwelling',
    '% of tenant households in subsidized housing',
    'Median monthly shelter costs for owned dwellings ($)',
    'Average monthly shelter costs for owned dwellings ($)',
    'Median value of dwellings ($)',
    'Average value of dwellings ($)',
    'Median monthly shelter costs for rented dwellings ($)',
    'Median monthly shelter costs for rented dwellings ($)',
    'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data',
    'No certificate, diploma or degree',
    'Secondary (high) school diploma or equivalency certificate',
    'Postsecondary certificate, diploma or degree',
    'College, CEGEP or other non-university certificate or diploma',
    'University certificate or diploma below bachelor level',
    'University certificate, diploma or degree at bachelor level or above',
    'Total - Location of study compared with province or territory of residence with countries outside Canada for the population aged 15 years and over in private households - 25% sample data',
    'Location of study inside Canada',
    'Same as province or territory of residence',
    'Different than province or territory of residence',
    'Location of study outside Canada',
    'Total - Population aged 15 years and over by Labour force status - 25% sample data',
    'In the labour force',
    'Not in the labour force',
    'Total - Main mode of commuting for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data',
    'Car, truck, van - as a driver',
    'Car, truck, van - as a passenger',
    'Public transit',
    'Walked',
    'Bicycle',
    'Other method',
    'Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data',
    'Less than 15 minutes',
    '15 to 29 minutes',
    '30 to 44 minutes',
    '45 to 59 minutes',
    '60 minutes and over',
    'Total - Mobility status 1 year ago - 25% sample data',
    'Non-movers',
    'Movers'
]


# output file name
# output_file_name = '/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/data_from_2016_into_2021_CTs.csv'
output_file_name = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/2016_into_2021_CTs_EN_v1.csv'

# read in the data
df = pd.read_csv(data_csv)

# read in crosswalk table
cw = pd.read_csv(crosswalk_csv)

# joining the two input tables
merge_cw_df = cw.merge(df, how = "inner", left_on = "source_ctuid", right_on = ctuidcol)
# print(merge_cw_df.head())
# loop over each field, multiplying by the apportionment weight
output_fields = []
for f in fields:
    print(f)
    merge_cw_df["w_" + f] = np.asarray(merge_cw_df["w_pop"]) * np.asarray( pd.to_numeric(merge_cw_df[f], errors='coerce'))
    output_fields.append("w_" + f)

# group by the target census tracts, summing by the wanted fields
output_data = merge_cw_df.groupby(["target_ctuid"]).sum()
output_data = output_data[output_fields]
output_data= output_data.astype(int)

# write to file
output_data.to_csv(output_file_name)
output_data.head()
# Out:
# Population, 2016
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population, 2016'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-ad3db4979bb8> in <cell line: 137>()
#     137 for f in fields:
#     138     print(f)
# --> 139     merge_cw_df["w_" + f] = np.asarray(merge_cw_df["w_pop"]) * np.asarray( pd.to_numeric(merge_cw_df[f], errors='coerce'))
#     140     output_fields.append("w_" + f)
#     141
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Population, 2016'

# %% [markdown]
# #  Combining Data Years Together

# %% [markdown]
# #  Cleaning Data

# %%
# Bucket Ages
# Merge and sum the columns
df['0 to 19 years 2016'] = df['0 to 14 years 2016'] + df['15 to 19 years 2016']
df['20 to 29 years 2016'] = df['20 to 24 years 2016'] + df['25 to 29 years 2016']
df['30 to 39 years 2016'] = df['30 to 34 years 2016'] + df['35 to 39 years 2016']
df['40 to 49 years 2016'] = df['40 to 44 years 2016'] + df['45 to 49 years 2016']
df['50 to 59 years 2016'] = df['50 to 54 years 2016'] + df['55 to 59 years 2016']
df['60 years and over 2016'] = df['60 to 64 years 2016'] + df['65 years and over 2016']


# Drop the original columns
df = df.drop(['0 to 14 years 2016', '15 to 19 years 2016', '20 to 24 years 2016',
              '25 to 29 years 2016', '30 to 34 years 2016', '35 to 39 years 2016',
              '40 to 44 years 2016', '45 to 49 years 2016', '50 to 54 years 2016',
              '55 to 59 years 2016', '60 to 64 years 2016', '65 years and over 2016'], axis=1)

# %% [markdown]
# # Adding Other External Data

# %% [markdown]
# # Testing Models
