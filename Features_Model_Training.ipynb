# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/Features_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/important_features_emilie.csv')
test = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/census_data_ding.csv')

# Get the number of columns
num_columns = len(df.columns)
num_rows = len(df)

# Print the number of columns
print(f'The number of columns in the dataset is: {num_columns}')
print(f'The number of rows in the dataset is: {num_rows}')

# Print the column names
print("Column names in the original file:")
for column in df.columns:
    print(column)
# Out:
# The number of columns in the dataset is: 143
# The number of rows in the dataset is: 1008
# Column names in the original file:
# ctuid
# All others 2001
# Apartment, building that has fewer than five storeys 2001
# Average gross rent $ 2001
# Average value of dwelling $ 2001
# Bicycle 2001
# Citizenship other than Canadian 2001
# Major repairs 2001
# Median household income $ 2001
# Movers 2001
# Non-movers 2001
# Other method 2001
# Other single-attached house 2001
# Owner households in non-farm, non-reserve private dwellings 2001
# Population percentage change, 1996-2001 2001
# Public transit 2001
# Regular maintenance only 2001
# Row house 2001
# Total visible minority population 2001
# Trades certificate or diploma 2001
# Walked 2001
# With bachelor's degree or higher 2001
# Without certificate or diploma 2001
# 50 to 59 years 2001
# Row house 2006
# Apartment, building that has fewer than five storeys 2006
# Other single-attached house 2006
# Regular maintenance only 2006
# Major repairs 2006
# Non-movers 2006
# Movers 2006
# Not Canadian citizens 2006
# Total population 15 to 24 years by highest certificate, diploma or degree - 20% sample data 2006
# No certificate, diploma or degree 2006
# Apprenticeship or trades certificate or diploma 2006
# University certificate or degree 2006
# Total visible minority population 2006
# Not a visible minority 2006
# Median household income $ 2006
# Median after-tax household income $ 2006
# Average gross rent $ 2006
# Average value of dwelling $ 2006
# 50 to 59 2006
# Owner-occupied private non-farm, non-reserve dwellings 2006
# Tenant-occupied private non-farm, non-reserve dwellings 2006
# Walked 2006
# Bicycle 2006
# Other method 2006
# Public transit 2006
# 2006 to 2011 population change (%) 2011
# Row house 2011
# Apartment, building that has fewer than five storeys 2011
# Other single-attached house 2011
# Not Canadian citizens 2011
# Total visible minority population 2011
# Not a visible minority 2011
# Non-movers 2011
# Movers 2011
# Total population aged 15 years and over by highest certificate, diploma or degree 2011
# No certificate, diploma or degree 2011
# Apprenticeship or trades certificate or diploma 2011
# University certificate, diploma or degree at bachelor level or above 2011
# Public transit 2011
# Walked 2011
# Bicycle 2011
# Other methods 2011
# Only regular maintenance or minor repairs needed 2011
# Major repairs needed 2011
# Average value of dwellings ($) 2011
# Number of tenant households in non-farm, non-reserve private dwellings 2011
# Median monthly shelter costs for rented dwellings ($) 2011
# Median after-tax income ($) 2011
# Median total income ($) 2011
# Population percentage change, 2011 to 2016 2016
# Row house 2016
# Apartment in a building that has fewer than five storeys 2016
# Other single-attached house 2016
# Median total income of households in 2015 ($) 2016
# Median after-tax income of households in 2015 ($) 2016
# Not Canadian citizens 2016
# Total visible minority population 2016
# Not a visible minority 2016
# Only regular maintenance or minor repairs needed 2016
# Major repairs needed 2016
# Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2016
# Average value of dwellings ($) 2016
# Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2016
# Median monthly shelter costs for rented dwellings ($) 2016
# No certificate, diploma or degree 2016
# Apprenticeship or trades certificate or diploma 2016
# University certificate, diploma or degree at bachelor level or above 2016
# Public transit 2016
# Walked 2016
# Bicycle 2016
# Other method 2016
# Non-movers 2016
# Movers 2016
# Population percentage change, 2016 to 2021 2021
# Row house 2021
# Apartment in a building that has fewer than five storeys 2021
# Other single-attached house 2021
# Median total income of household in 2020 ($) 2021
# Median after-tax income of household in 2020 ($) 2021
# Only regular maintenance and minor repairs needed 2021
# Major repairs needed 2021
# Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2021
# Average value of dwellings ($) 2021
# Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2021
# Median monthly shelter costs for rented dwellings ($) 2021
# Not Canadian citizens 2021
# Total visible minority population 2021
# Not a visible minority 2021
# Non-movers 2021
# Movers 2021
# Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2021
# No certificate, diploma or degree 2021
# Apprenticeship or trades certificate or diploma 2021
# Bachelor's degree or higher 2021
# Public transit 2021
# Walked 2021
# Bicycle 2021
# Other method 2021
# Gentrifiable Ding 2021
# Gentrifiable Ding 2016
# Gentrifiable Ding 2011
# Gentrifiable Ding 2006
# Gentrifiable Ding 2001
# Gentrified Ding 2021
# Gentrified Ding 2016
# Gentrified Ding 2011
# Gentrified Ding 2006
# Gentrified Ding 2001
# Gentrification Level Ding 2021
# Gentrification Level Ding 2016
# Gentrification Level Ding 2011
# Gentrification Level Ding 2006
# Gentrification Level Ding 2001
# Population percentage change, 2001-2006 2006
# 50 to 59 years 2011
# 50 to 59 years 2016
# 50 to 59 years 2021
# Highest certificate, diploma or degree for the population 2001
# Highest certificate, diploma or degree for the population 2016

# %%
column_name = "Population percentage change, 2001-2006 2006"

# Calculate the average of non-inf values
average_without_inf = df.loc[~df[column_name].isin([np.inf, -np.inf]), column_name].mean()

# Replace inf values with the calculated average
df['Population percentage change, 2001-2006 2006'].replace([np.inf, -np.inf], average_without_inf, inplace=True)

# %%
# bucket columns into same feature for each year
major_repairs = ["Major repairs 2001", "Major repairs 2006", "Major repairs needed 2011", "Major repairs needed 2016", "Major repairs needed 2021"]
gentrifiable_ding = ["Gentrifiable Ding 2001", "Gentrifiable Ding 2006", "Gentrifiable Ding 2011", "Gentrifiable Ding 2016", "Gentrifiable Ding 2021"]
median_household_income_after_tax = ["Median household income $ 2001", "Median after-tax household income $ 2006", "Median after-tax income ($) 2011", "Median after-tax income of households in 2015 ($) 2016", "Median after-tax income of household in 2020 ($) 2021"]
other_single_attached_house = ["Other single-attached house 2001", "Other single-attached house 2006", "Other single-attached house 2011", "Other single-attached house 2016", "Other single-attached house 2021"]
trades_certificate_or_diploma = ["Trades certificate or diploma 2001", "Apprenticeship or trades certificate or diploma 2006", "Apprenticeship or trades certificate or diploma 2011", "Apprenticeship or trades certificate or diploma 2016", "Apprenticeship or trades certificate or diploma 2021"]
apartment_fewer_than_five_storeys = ["Apartment, building that has fewer than five storeys 2001", "Apartment, building that has fewer than five storeys 2006", "Apartment, building that has fewer than five storeys 2011", "Apartment in a building that has fewer than five storeys 2016", "Apartment in a building that has fewer than five storeys 2021"]
without_certificate_or_diploma = ["Without certificate or diploma 2001", "No certificate, diploma or degree 2006", "No certificate, diploma or degree 2011", "No certificate, diploma or degree 2016", "No certificate, diploma or degree 2021"]
total_visible_minority_population = ["Total visible minority population 2001", "Total visible minority population 2006", "Total visible minority population 2011", "Total visible minority population 2016", "Total visible minority population 2021"]
movers = ["Movers 2001", "Movers 2006", "Movers 2011", "Movers 2016", "Movers 2021"]
row_house = ["Row house 2001", "Row house 2006", "Row house 2011", "Row house 2016", "Row house 2021"]
years_50_to_59 = ["50 to 59 years 2001", "50 to 59 2006", "50 to 59 years 2011", "50 to 59 years 2016", "50 to 59 years 2021"]
regular_maintenance = ["Regular maintenance only 2001", "Regular maintenance only 2006", "Only regular maintenance or minor repairs needed 2011", "Only regular maintenance or minor repairs needed 2016", "Only regular maintenance and minor repairs needed 2021"]
non_movers = ["Non-movers 2001", "Non-movers 2006", "Non-movers 2011", "Non-movers 2016", "Non-movers 2021"]
all_others = ["All others 2001", "Not a visible minority 2006", "Not a visible minority 2011", "Not a visible minority 2016", "Not a visible minority 2021"]
citizenship = ["Citizenship other than Canadian 2001", "Not Canadian citizens 2006", "Not Canadian citizens 2011", "Not Canadian citizens 2016", "Not Canadian citizens 2021"]
bicycle = ["Bicycle 2001", "Bicycle 2006", "Bicycle 2011", "Bicycle 2016", "Bicycle 2021"]
population_change = ["Population percentage change, 1996-2001 2001", "Population percentage change, 2001-2006 2006", "2006 to 2011 population change (%) 2011", "Population percentage change, 2011 to 2016 2016", "Population percentage change, 2016 to 2021 2021"]
public_transit = ["Public transit 2001", "Public transit 2006", "Public transit 2011", "Public transit 2016", "Public transit 2021"]
walked = ["Walked 2001", "Walked 2006", "Walked 2011", "Walked 2016", "Walked 2021"]
other_method = ["Other method 2001", "Other method 2006", "Other methods 2011", "Other method 2016", "Other method 2021"]
gentrified_ding = ["Gentrified Ding 2001", "Gentrified Ding 2006", "Gentrified Ding 2011", "Gentrified Ding 2016", "Gentrified Ding 2021"]
bachelor_degree_or_higher = ["With bachelor's degree or higher 2001", "University certificate or degree 2006", "University certificate, diploma or degree at bachelor level or above 2011", "University certificate, diploma or degree at bachelor level or above 2016", "Bachelor's degree or higher 2021"]
median_household_income = ["Median household income $ 2001", "Median household income $ 2006", "Median total income ($) 2011", "Median total income of households in 2015 ($) 2016", "Median total income of household in 2020 ($) 2021"]
owner_households = ["Owner households in non-farm, non-reserve private dwellings 2001", "Owner-occupied private non-farm, non-reserve dwellings 2006", "Number of tenant households in non-farm, non-reserve private dwellings 2011", "Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2016", "Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2021"]
average_value_dwelling = ["Average value of dwelling $ 2001", "Average value of dwelling $ 2006", "Average value of dwellings ($) 2011", "Average value of dwellings ($) 2016", "Average value of dwellings ($) 2021"]
tenant_households = ["Owner households in non-farm, non-reserve private dwellings 2001", "Tenant-occupied private non-farm, non-reserve dwellings 2006", "Number of tenant households in non-farm, non-reserve private dwellings 2011", "Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2016", "Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2021"]
average_gross_rent = ["Average gross rent $ 2001", "Average gross rent $ 2006", "Median monthly shelter costs for rented dwellings ($) 2011", "Median monthly shelter costs for rented dwellings ($) 2016", "Median monthly shelter costs for rented dwellings ($) 2021"]
highest_certificate = ["Highest certificate, diploma or degree for the population 2001", "Total population 15 to 24 years by highest certificate, diploma or degree - 20% sample data 2006", "Total population aged 15 years and over by highest certificate, diploma or degree 2011", "Highest certificate, diploma or degree for the population 2016", "Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2021"]
gentrification_level = ["Gentrification Level Ding 2001", "Gentrification Level Ding 2006", "Gentrification Level Ding 2011", "Gentrification Level Ding 2016", "Gentrification Level Ding 2021"]

# Combine all lists into one list of lists
column_lists = [major_repairs, gentrifiable_ding, median_household_income_after_tax, median_household_income,  # Include it twice
                other_single_attached_house, trades_certificate_or_diploma, apartment_fewer_than_five_storeys,
                without_certificate_or_diploma, total_visible_minority_population, movers, row_house, years_50_to_59,
                regular_maintenance, non_movers, all_others, citizenship, bicycle, population_change, public_transit,
                walked, other_method, gentrified_ding, bachelor_degree_or_higher, median_household_income, owner_households,
                average_value_dwelling, tenant_households, average_gross_rent, highest_certificate, gentrification_level]


# Feature names for each list
feature_names = [
    "Major repairs", "Gentrifiable Ding", "Median household income after tax", "Median household income before tax",
    "Trades certificate or diploma", "Apartment, building that has fewer than five storeys",
    "Without certificate or diploma", "Total visible minority population", "Movers", "Row house",
    "50 to 59 years", "Regular maintenance", "Non-movers", "All others", "Citizenship", "Bicycle",
    "Population change", "Public transit", "Walked", "Other method", "Gentrified Ding",
    "Bachelor's degree or higher", "Median household income (before tax)", "Owner households", "Average value dwelling",
    "Tenant households", "Average gross rent", "Highest certificate", "Gentrification level"
]

# Create a dictionary to store new columns
new_columns = {}

# Create new columns in the dictionary
for column_list, feature_name in zip(column_lists, feature_names):
    for column in column_list:
        # Extract the year from the column name
        year = column.split()[-1]
        # Create the new column name
        new_name = f'{feature_name} {year}'
        # Assign the values to the new column in the dictionary
        new_columns[new_name] = df[column]

# Insert the 'ctuid' column as the first column in the new DataFrame
new_columns['ctuid'] = df['ctuid']

# Create the new DataFrame
new_df = pd.DataFrame(new_columns)

print(new_df)
# Out:
#       Major repairs 2001  Major repairs 2006  Major repairs 2011  \
# 0                    0.0                 0.0                 0.0
# 1                  110.0               120.0               125.0
# 2                  105.0               100.0               145.0
# 3                  105.0               100.0               145.0
# 4                  200.0               220.0               240.0
# ...                  ...                 ...                 ...
# 1003                 NaN                 NaN                 NaN
# 1004                 NaN                 NaN                 NaN
# 1005                 NaN                 NaN                 NaN
# 1006                 NaN                 NaN                 NaN
# 1007                 NaN                 NaN                 NaN
#
#       Major repairs 2016  Major repairs 2021  Gentrifiable Ding 2001  \
# 0                    0.0                 NaN                    True
# 1                  105.0               175.0                    True
# 2                  130.0               125.0                    True
# 3                  130.0                 NaN                    True
# 4                  235.0               245.0                    True
# ...                  ...                 ...                     ...
# 1003                15.0                35.0                   False
# 1004                90.0                95.0                   False
# 1005                75.0                70.0                   False
# 1006                 0.0                 NaN                   False
# 1007                 NaN            122850.0                   False
#
#       Gentrifiable Ding 2006  Gentrifiable Ding 2011  Gentrifiable Ding 2016  \
# 0                       True                    True                    True
# 1                       True                    True                    True
# 2                       True                    True                    True
# 3                       True                    True                    True
# 4                       True                    True                    True
# ...                      ...                     ...                     ...
# 1003                   False                   False                   False
# 1004                   False                   False                   False
# 1005                   False                   False                   False
# 1006                   False                   False                    True
# 1007                   False                   False                   False
#
#       Gentrifiable Ding 2021  ...  Highest certificate 2006  \
# 0                      False  ...                       0.0
# 1                       True  ...                     630.0
# 2                       True  ...                     615.0
# 3                      False  ...                     615.0
# 4                       True  ...                     613.0
# ...                      ...  ...                       ...
# 1003                   False  ...                       NaN
# 1004                   False  ...                       NaN
# 1005                   False  ...                       NaN
# 1006                   False  ...                       NaN
# 1007                   False  ...                       NaN
#
#       Highest certificate 2011  Highest certificate 2016  \
# 0                          0.0                       0.0
# 1                        594.0                     731.0
# 2                        682.0                     727.0
# 3                        682.0                     727.0
# 4                        643.0                     711.0
# ...                        ...                       ...
# 1003                       NaN                     642.0
# 1004                       NaN                     768.0
# 1005                       NaN                     770.0
# 1006                       NaN                       0.0
# 1007                       NaN                       NaN
#
#       Highest certificate 2021  Gentrification level 2001  \
# 0                          NaN              -9.222615e+18
# 1                        840.0              -9.217321e+18
# 2                        790.0              -9.217326e+18
# 3                          NaN              -9.217326e+18
# 4                        800.0              -1.844674e+19
# ...                        ...                        ...
# 1003                     710.0               0.000000e+00
# 1004                     830.0               0.000000e+00
# 1005                     980.0               0.000000e+00
# 1006                       NaN               0.000000e+00
# 1007                     880.0               0.000000e+00
#
#       Gentrification level 2006  Gentrification level 2011  \
# 0                           0.0                        0.0
# 1                        2155.0                     2230.0
# 2                        2390.0                     2650.0
# 3                        2390.0                     2650.0
# 4                        5420.0                     5275.0
# ...                         ...                        ...
# 1003                        0.0                        0.0
# 1004                        0.0                        0.0
# 1005                        0.0                        0.0
# 1006                        0.0                        0.0
# 1007                        0.0                        0.0
#
#       Gentrification level 2016  Gentrification level 2021      ctuid
# 0                           0.0                        0.0       -1.0
# 1                        2285.0                     2200.0  4620001.0
# 2                        2870.0                     3120.0  4620002.0
# 3                        2870.0                        0.0  4620002.0
# 4                        5245.0                     5495.0  4620003.0
# ...                         ...                        ...        ...
# 1003                      890.0                      850.0  4622304.0
# 1004                     2310.0                     2280.0  4622400.0
# 1005                     2880.0                     3230.0  4622401.0
# 1006                        0.0                        0.0  4622402.0
# 1007                        0.0                  3485575.0      462.0
#
# [1008 rows x 146 columns]

# %%
# Create dictionaries to hold columns for each year
year_columns = {year: [] for year in ['2001', '2006', '2011', '2016', '2021']}

# Populate the dictionaries with the respective columns
for column in new_df.columns:
    if column != 'ctuid':  # Skip 'ctuid' column
        year = column.split()[-1]
        if year in year_columns:
            year_columns[year].append(column)

# Sort the columns for each year alphabetically
for year in year_columns:
    year_columns[year].sort()

# Combine all columns in the desired order
new_column_order = ['ctuid']
for year in ['2001', '2006', '2011', '2016', '2021']:
    new_column_order.extend(year_columns[year])

# Reorder the DataFrame columns
df = new_df[new_column_order]

print(df)
# Out:
#           ctuid  50 to 59 years 2001  All others 2001  \
# 0          -1.0                  0.0              0.0
# 1     4620001.0                 40.0           2180.0
# 2     4620002.0                140.0           2275.0
# 3     4620002.0                140.0           2275.0
# 4     4620003.0                135.0           5435.0
# ...         ...                  ...              ...
# 1003  4622304.0                  NaN              NaN
# 1004  4622400.0                  NaN              NaN
# 1005  4622401.0                  NaN              NaN
# 1006  4622402.0                  NaN              NaN
# 1007      462.0                  NaN              NaN
#
#       Apartment, building that has fewer than five storeys 2001  \
# 0                                                   0.0
# 1                                                 290.0
# 2                                                 270.0
# 3                                                 270.0
# 4                                                 510.0
# ...                                                 ...
# 1003                                                NaN
# 1004                                                NaN
# 1005                                                NaN
# 1006                                                NaN
# 1007                                                NaN
#
#       Average gross rent 2001  Average value dwelling 2001  \
# 0                         0.0                          0.0
# 1                       440.0                        440.0
# 2                       435.0                        435.0
# 3                       435.0                        435.0
# 4                      1105.0                       1105.0
# ...                       ...                          ...
# 1003                      NaN                          NaN
# 1004                      NaN                          NaN
# 1005                      NaN                          NaN
# 1006                      NaN                          NaN
# 1007                      NaN                          NaN
#
#       Bachelor's degree or higher 2001  Bicycle 2001  Citizenship 2001  \
# 0                                False           0.0               0.0
# 1                                 True           0.0            2395.0
# 2                                 True          15.0            2595.0
# 3                                 True          15.0            2595.0
# 4                                False         105.0            6065.0
# ...                                ...           ...               ...
# 1003                             False           NaN               NaN
# 1004                             False           NaN               NaN
# 1005                             False           NaN               NaN
# 1006                             False           NaN               NaN
# 1007                             False           NaN               NaN
#
#       Gentrifiable Ding 2001  ...  Owner households 2021  \
# 0                       True  ...                    NaN
# 1                       True  ...                63600.0
# 2                       True  ...                57600.0
# 3                       True  ...                    NaN
# 4                       True  ...                62000.0
# ...                      ...  ...                    ...
# 1003                   False  ...                92000.0
# 1004                   False  ...                80000.0
# 1005                   False  ...               100000.0
# 1006                   False  ...                    NaN
# 1007                   False  ...                76000.0
#
#       Population change 2021  Public transit 2021  Regular maintenance 2021  \
# 0                        NaN                  NaN                       0.0
# 1                       20.0                  1.7                     405.0
# 2                        NaN                  7.5                     525.0
# 3                       10.0                  NaN                       0.0
# 4                       50.0                  3.6                     875.0
# ...                      ...                  ...                       ...
# 1003                     0.0                 -2.4                     150.0
# 1004                     0.0                  1.8                     370.0
# 1005                     0.0                 10.8                     540.0
# 1006                     NaN                  NaN                       0.0
# 1007                 28240.0                  4.6                  566970.0
#
#       Row house 2021  Tenant households 2021  \
# 0                NaN                     NaN
# 1             1175.0                370000.0
# 2             1665.0                356000.0
# 3                NaN                     NaN
# 4             2625.0                474000.0
# ...              ...                     ...
# 1003           215.0                380000.0
# 1004           960.0                353000.0
# 1005          1550.0                395600.0
# 1006             NaN                     NaN
# 1007       1641640.0                500400.0
#
#       Total visible minority population 2021  \
# 0                                        NaN
# 1                                      265.0
# 2                                      350.0
# 3                                        NaN
# 4                                      470.0
# ...                                      ...
# 1003                                    50.0
# 1004                                   250.0
# 1005                                   260.0
# 1006                                     NaN
# 1007                                229890.0
#
#       Trades certificate or diploma 2021  Walked 2021  \
# 0                                    NaN          NaN
# 1                                   15.0        170.0
# 2                                   30.0          NaN
# 3                                    NaN        365.0
# 4                                   20.0        725.0
# ...                                  ...          ...
# 1003                                 0.0         10.0
# 1004                                 5.0          0.0
# 1005                                15.0         30.0
# 1006                                 NaN          NaN
# 1007                              6420.0     239280.0
#
#       Without certificate or diploma 2021
# 0                                     NaN
# 1                                   860.0
# 2                                  1165.0
# 3                                     NaN
# 4                                  1705.0
# ...                                   ...
# 1003                                 25.0
# 1004                                 75.0
# 1005                                160.0
# 1006                                  NaN
# 1007                             758875.0
#
# [1008 rows x 146 columns]

# %%
# Specify the path for the new file
new_file_path = '/content/drive/MyDrive/GentrificAItion/ModelOutputs/features.csv'

# Save the resulting DataFrame with only the specified columns to the new file
df.to_csv(new_file_path, index=False)
