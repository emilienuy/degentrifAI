# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/ImportantFeatures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/census_data_ding.csv')

# Get the number of columns
num_columns = len(data.columns)

# Print the number of columns
print(f'The number of columns in the dataset is: {num_columns}')
# Out:
# The number of columns in the dataset is: 549

# %%
import pandas as pd

# Load the original dataset
original_data = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/census_data_ding.csv')

# Get the column names
original_column_names = original_data.columns

# Print the column names
print("Column names in the original file:")
for column in original_column_names:
    print(column)
# Out:
# Column names in the original file:
# Unnamed: 0.1
# ctuid
# All others 2001
# Apartment, building that has fewer than five storeys 2001
# Apartment, building that has five or more storeys 2001
# Apartment, detached duplex 2001
# Average gross rent $ 2001
# Average household income $ 2001
# Average income $ 2001
# Average number of persons in private households 2001
# Average value of dwelling $ 2001
# Band housing 2001
# Bicycle 2001
# Born in province of residence 2001
# Born outside province of residence 2001
# Canadian citizenship 2001
# Car, truck, van, as driver 2001
# Car, truck, van, as passenger 2001
# Citizenship other than Canadian 2001
# College 2001
# Dwellings  2001
# Employment rate 2001
# Female, total 2001
# Females 2001
# Females with usual place of work or no fixed workplace address 2001
# GeoUID 2001
# Grades 9 to 13 2001
# Household income in 2000 of all private households 2001
# Households  2001
# Land area in square kilometres, 2001 2001
# ...

# %% [markdown]
# Shows all the columns minus the ones dropped

# %%
# specificy which columns used to predict 2021 Ding measure
# Gentrifiable_2021 = ["Median total income of household in 2020 ($) 2021"]
Gentrified_2021 = ["Average value of dwellings ($) 2021",
                   "Median monthly shelter costs for rented dwellings ($) 2021",
                   "Bachelor's degree or higher 2021"]

# remove intensity gentrified ding measures:
Gen_Intensity_2021 = ["Gentrification Level Ding 2021"]

# drop these columns
data = data.drop(Gentrified_2021, axis=1)
data = data.drop(Gen_Intensity_2021, axis=1)

# Display the number of columns and the remaining column names after dropping
print(f'The number of columns after dropping is: {len(data.columns)}')
print('The remaining column names are:')
for col in data.columns:
    print(col)
# Out:
# The number of columns after dropping is: 545
# The remaining column names are:
# Unnamed: 0.1
# ctuid
# All others 2001
# Apartment, building that has fewer than five storeys 2001
# Apartment, building that has five or more storeys 2001
# Apartment, detached duplex 2001
# Average gross rent $ 2001
# Average household income $ 2001
# Average income $ 2001
# Average number of persons in private households 2001
# Average value of dwelling $ 2001
# Band housing 2001
# Bicycle 2001
# Born in province of residence 2001
# Born outside province of residence 2001
# Canadian citizenship 2001
# Car, truck, van, as driver 2001
# Car, truck, van, as passenger 2001
# Citizenship other than Canadian 2001
# College 2001
# Dwellings  2001
# Employment rate 2001
# Female, total 2001
# Females 2001
# Females with usual place of work or no fixed workplace address 2001
# GeoUID 2001
# Grades 9 to 13 2001
# Household income in 2000 of all private households 2001
# Households  2001
# ...

# %% [markdown]
# Important features extraction

# %% [markdown]
# **Original order of Ding File with dropped columns minus the combined data for highest certificate, diploma or degree**

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/census_data_ding.csv')

# List of column names you want to keep (in any order)
columns_to_keep = [
    'cuid', 'Major repairs 2001', 'Major repairs 2006', 'Major repairs needed 2011', 'Major repairs needed 2016', 'Major repairs needed 2021',
    'Gentrifiable Ding 2001', 'Gentrifiable Ding 2006', 'Gentrifiable Ding 2011', 'Gentrifiable Ding 2016', 'Gentrifiable Ding 2021',
    'Median household income $ 2001', 'Median after-tax household income $ 2006', 'Median after-tax income ($) 2011', 'Median after-tax income of households in 2015 ($) 2016', 'Median after-tax income of household in 2020 ($) 2021',
    'Other single-attached house 2001', 'Other single-attached house 2006', 'Other single-attached house 2011', 'Other single-attached house 2016', 'Other single-attached house 2021',
    'Trades certificate or diploma 2001', 'Apprenticeship or trades certificate or diploma 2006', 'Apprenticeship or trades certificate or diploma 2011', 'Apprenticeship or trades certificate or diploma 2016', 'Apprenticeship or trades certificate or diploma 2021',
    'Apartment, building that has fewer than five storeys 2001', 'Apartment, building that has fewer than five storeys 2006', 'Apartment, building that has fewer than five storeys 2011', 'Apartment in a building that has fewer than five storeys 2016', 'Apartment in a building that has fewer than five storeys 2021',
    'Without certificate or diploma 2001', 'No certificate, diploma or degree 2006', 'No certificate, diploma or degree 2011', 'No certificate, diploma or degree 2016', 'No certificate, diploma or degree 2021',
    'Total visible minority population 2001', 'Total visible minority population 2006', 'Total visible minority population 2011', 'Total visible minority population 2016', 'Total visible minority population 2021',
    'Movers 2001', 'Movers 2006', 'Movers 2011', 'Movers 2016', 'Movers 2021',
    'Row house 2001', 'Row house 2006', 'Row house 2011', 'Row house 2016', 'Row house 2021',
    '50 to 59 years 2001', 'Age 50 to 59 2006', '50 to 59 years 2011', '50 to 59 years 2016', '50 to 59 years 2021',
    'Regular maintenance only 2001', 'Regular maintenance only 2006', 'Only regular maintenance or minor repairs needed 2011', 'Only regular maintenance or minor repairs needed 2016', 'Only regular maintenance and minor repairs needed 2021',
    'Non-movers 2001', 'Non-movers 2006', 'Non-movers 2011', 'Non-movers 2016', 'Non-movers 2021',
    'All others 2001', 'Not a visible minority 2006', 'Not a visible minority 2011', 'Not a visible minority 2016', 'Not a visible minority 2021',
    'Citizenship other than Canadian 2001', 'Not Canadian citizens 2006', 'Not Canadian citizens 2011', 'Not Canadian citizens 2016', 'Not Canadian citizens 2021',
    'Bicycle 2001', 'Bicycle 2006', 'Bicycle 2011', 'Bicycle 2016', 'Bicycle 2021',
    'Population percentage change, 1996-2001 2001', 'Population percentage change, 2001-2006 2006', '2006 to 2011 population change (%) 2011', 'Population percentage change, 2011 to 2016 2016', 'Population percentage change, 2016 to 2021 2021',
    'Public transit 2001', 'Public transit 2006', 'Public transit 2011', 'Public transit 2016', 'Public transit 2021',
    'Walked 2001', 'Walked 2006', 'Walked 2011', 'Walked 2016', 'Walked 2021',
    'Other method 2001', 'Other method 2006', 'Other methods 2011', 'Other method 2016', 'Other method 2021', 'Gentrified Ding 2001', 'Gentrified Ding 2006', 'Gentrified Ding 2011', 'Gentrified Ding 2016', 'Gentrified Ding 2021',
    'With bachelor\'s degree or higher 2001', 'University certificate or degree 2006', 'University certificate, diploma or degree at bachelor level or above 2011', 'University certificate, diploma or degree at bachelor level or above 2016', 'Bachelor\'s degree or higher 2021',
    'Median household income $ 2001', 'Median household income $ 2006', 'Median total income ($) 2011', 'Median total income of households in 2015 ($) 2016', 'Median total income of household in 2020 ($) 2021',
    'Owner households in non-farm, non-reserve private dwellings 2001', 'Owner-occupied private non-farm, non-reserve dwellings 2006', 'Number of tenant households in non-farm, non-reserve private dwellings 2011', 'Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2016', 'Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2021',
    'Average value of dwelling $ 2001', 'Average value of dwelling $ 2006', 'Average value of dwellings ($) 2011', 'Average value of dwellings ($) 2016', 'Average value of dwellings ($) 2021',
    'Owner households in non-farm, non-reserve private dwellings 2001', 'Tenant-occupied private non-farm, non-reserve dwellings 2006', 'Number of tenant households in non-farm, non-reserve private dwellings 2011', 'Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2016', 'Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2021',
    'Average gross rent $ 2001', 'Average gross rent $ 2006', 'Median monthly shelter costs for rented dwellings ($) 2011', 'Median monthly shelter costs for rented dwellings ($) 2016', 'Median monthly shelter costs for rented dwellings ($) 2021'
]

# Keep only the specified columns in their original order
filtered_data = data[[col for col in data.columns if col in columns_to_keep]]

# Specify the path for the new file
new_file_path = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/important_features.csv'

# Save the resulting DataFrame with only the specified columns to the new file
filtered_data.to_csv(new_file_path, index=False)

# Print confirmation with correct path formatting
print(f"New file with only specified columns saved to: {new_file_path}")
# Out:
# New file with only specified columns saved to: /content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/important_features.csv

# %% [markdown]
# **Combined data for highest certificate, diploma or degree**

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/census_data_ding.csv')

# List of column names you want to keep
columns_to_keep = [
    'cuid','Major repairs 2001', 'Major repairs 2006', 'Major repairs needed 2011', 'Major repairs needed 2016', 'Major repairs needed 2021',
    'Gentrifiable Ding 2001', 'Gentrifiable Ding 2006', 'Gentrifiable Ding 2011', 'Gentrifiable Ding 2016', 'Gentrifiable Ding 2021',
    'Median household income $ 2001', 'Median after-tax household income $ 2006', 'Median after-tax income ($) 2011', 'Median after-tax income of households in 2015 ($) 2016', 'Median after-tax income of household in 2020 ($) 2021',
    'Other single-attached house 2001', 'Other single-attached house 2006', 'Other single-attached house 2011', 'Other single-attached house 2016', 'Other single-attached house 2021',
    'Trades certificate or diploma 2001', 'Apprenticeship or trades certificate or diploma 2006', 'Apprenticeship or trades certificate or diploma 2011', 'Apprenticeship or trades certificate or diploma 2016', 'Apprenticeship or trades certificate or diploma 2021',
    'Apartment, building that has fewer than five storeys 2001', 'Apartment, building that has fewer than five storeys 2006', 'Apartment, building that has fewer than five storeys 2011', 'Apartment in a building that has fewer than five storeys 2016', 'Apartment in a building that has fewer than five storeys 2021',
    'Without certificate or diploma 2001', 'No certificate, diploma or degree 2006', 'No certificate, diploma or degree 2011', 'No certificate, diploma or degree 2016', 'No certificate, diploma or degree 2021',
    'Total visible minority population 2001', 'Total visible minority population 2006', 'Total visible minority population 2011', 'Total visible minority population 2016', 'Total visible minority population 2021',
    'Movers 2001', 'Movers 2006', 'Movers 2011', 'Movers 2016', 'Movers 2021',
    'Row house 2001', 'Row house 2006', 'Row house 2011', 'Row house 2016', 'Row house 2021',
    '50 to 59 years 2001', 'Age 50 to 59 2006', '50 to 59 years 2011', '50 to 59 years 2016', '50 to 59 years 2021',
    'Regular maintenance only 2001', 'Regular maintenance only 2006', 'Only regular maintenance or minor repairs needed 2011', 'Only regular maintenance or minor repairs needed 2016', 'Only regular maintenance and minor repairs needed 2021',
    'Non-movers 2001', 'Non-movers 2006', 'Non-movers 2011', 'Non-movers 2016', 'Non-movers 2021',
    'All others 2001', 'Not a visible minority 2006', 'Not a visible minority 2011', 'Not a visible minority 2016', 'Not a visible minority 2021',
    'Citizenship other than Canadian 2001', 'Not Canadian citizens 2006', 'Not Canadian citizens 2011', 'Not Canadian citizens 2016', 'Not Canadian citizens 2021',
    'Bicycle 2001', 'Bicycle 2006', 'Bicycle 2011', 'Bicycle 2016', 'Bicycle 2021',
    'Population percentage change, 1996-2001 2001', 'Population percentage change, 2001-2006 2006', '2006 to 2011 population change (%) 2011', 'Population percentage change, 2011 to 2016 2016', 'Population percentage change, 2016 to 2021 2021',
    'Public transit 2001', 'Public transit 2006', 'Public transit 2011', 'Public transit 2016', 'Public transit 2021',
    'Walked 2001', 'Walked 2006', 'Walked 2011', 'Walked 2016', 'Walked 2021',
    'Other method 2001', 'Other method 2006', 'Other methods 2011', 'Other method 2016', 'Other method 2021',
    'Gentrified Ding 2001', 'Gentrified Ding 2006', 'Gentrified Ding 2011', 'Gentrified Ding 2016', 'Gentrified Ding 2021',
    'With bachelor\'s degree or higher 2001', 'University certificate or degree 2006', 'University certificate, diploma or degree at bachelor level or above 2011', 'University certificate, diploma or degree at bachelor level or above 2016', 'Bachelor\'s degree or higher 2021',
    'Median household income $ 2001', 'Median household income $ 2006', 'Median total income ($) 2011', 'Median total income of households in 2015 ($) 2016', 'Median total income of household in 2020 ($) 2021',
    'Owner households in non-farm, non-reserve private dwellings 2001', 'Owner-occupied private non-farm, non-reserve dwellings 2006', 'Number of tenant households in non-farm, non-reserve private dwellings 2011', 'Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2016', 'Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data 2021',
    'Average value of dwelling $ 2001', 'Average value of dwelling $ 2006', 'Average value of dwellings ($) 2011', 'Average value of dwellings ($) 2016', 'Average value of dwellings ($) 2021',
    'Owner households in non-farm, non-reserve private dwellings 2001', 'Tenant-occupied private non-farm, non-reserve dwellings 2006', 'Number of tenant households in non-farm, non-reserve private dwellings 2011', 'Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2016', 'Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data 2021',
    'Average gross rent $ 2001', 'Average gross rent $ 2006', 'Median monthly shelter costs for rented dwellings ($) 2011', 'Median monthly shelter costs for rented dwellings ($) 2016', 'Median monthly shelter costs for rented dwellings ($) 2021', 'Gentrification Level Ding 2021', 'Gentrification Level Ding 2016', 'Gentrification Level Ding 2011', 'Gentrification Level Ding 2006', 'Gentrification Level Ding 2001', 'ctuid'

]

# Define columns to combine for each year
columns_2001 = ['0 to 19 years 2001', '30 to 39 years 2001', '40 to 49 years 2001', '50 to 59 years 2001', '60+ years 2001']
columns_2006 = ['Total population 15 to 24 years by highest certificate, diploma or degree - 20% sample data 2006',
                'Total population 25 to 64 years by highest certificate, diploma or degree - 20% sample data 2006',
                'Total population 65 years and over by highest certificate, diploma or degree - 20% sample data 2006']
columns_2011 = ['Total population aged 15 years and over by highest certificate, diploma or degree 2011']
columns_2016 = ['Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2016']
columns_2021 = ['Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2021']

# Combine the columns for each year into a single column and rename them
data['Highest certificate, diploma or degree for the population 2001'] = data[columns_2001].sum(axis=1)
data['Highest certificate, diploma or degree for the population 2016'] = data[columns_2016].sum(axis=1)

# Retain original names for the other combined columns
data['Total population 15 to 24 years by highest certificate, diploma or degree - 20% sample data 2006'] = data[columns_2006].sum(axis=1)
data['Total population aged 15 years and over by highest certificate, diploma or degree 2011'] = data[columns_2011].sum(axis=1)
data['Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2021'] = data[columns_2021].sum(axis=1)

# Include the combined columns in the columns_to_keep list
columns_to_keep.extend([
    'Highest certificate, diploma or degree for the population 2001',
    'Total population 15 to 24 years by highest certificate, diploma or degree - 20% sample data 2006',
    'Total population aged 15 years and over by highest certificate, diploma or degree 2011',
    'Highest certificate, diploma or degree for the population 2016',
    'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2021'
])

# Keep only the specified columns in their original order
filtered_data = data[[col for col in data.columns if col in columns_to_keep]]

# Specify the path for the new file
new_file_path = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/important_features.csv'

# Save the resulting DataFrame with only the specified columns to the new file
filtered_data.to_csv(new_file_path, index=False)

# Print confirmation with correct path formatting
print(f"New file with only specified columns saved to: {new_file_path}")
# Out:
# New file with only specified columns saved to: /content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/important_features.csv

# %%
# Load the new dataset
new_data = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/important_features.csv')

# Count the number of columns
num_columns = len(new_data.columns)

# Print the number of columns
print(f"Number of columns in the new file: {num_columns}")
# Out:
# Number of columns in the new file: 100
