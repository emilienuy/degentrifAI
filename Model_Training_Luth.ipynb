# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/Model_Training_Luth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Model 1**
# - File: census_data_ding.csv
# - Model: XGBoost
# - Location: Process Page Website
#
# 1. Original File: 537 columns

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/census_data_ding.csv')

# Get the number of columns
num_columns = len(data.columns)

# Print the number of columns
print(f'The number of columns in the dataset is: {num_columns}')
# Out:
# The number of columns in the dataset is: 537

# %%
# Print the column names
print('The column names are:')
print(data.columns)
# Out:
# The column names are:
# Index(['Unnamed: 0.1', 'ctuid', 'All others 2001',
#        'Apartment, building that has fewer than five storeys 2001',
#        'Apartment, building that has five or more storeys 2001',
#        'Apartment, detached duplex 2001', 'Average gross rent $ 2001',
#        'Average household income $ 2001', 'Average income $ 2001',
#        'Average number of persons in private households 2001',
#        ...
#        'Population, 2021 2021', 'Gentrifiable Ding 2021',
#        'Gentrifiable Ding 2016', 'Gentrifiable Ding 2011',
#        'Gentrifiable Ding 2006', 'Gentrifiable Ding 2001',
#        'Gentrified Ding 2021', 'Gentrified Ding 2016', 'Gentrified Ding 2011',
#        'Gentrified Ding 2006'],
#       dtype='object', length=537)

# %%
# List of columns to drop
columns_to_drop = [
    "Median total income of household in 2020 ($) 2021",
    "Average value of dwellings ($) 2021",
    "Median monthly shelter costs for rented dwellings ($) 2021",
    "Bachelor's degree or higher 2021"
]

# Drop the specified columns
data = data.drop(columns=columns_to_drop)

# Display the number of columns and the remaining column names after dropping
print(f'The number of columns after dropping is: {len(data.columns)}')
print('The remaining column names are:')
for col in data.columns:
    print(col)
# Out:
# The number of columns after dropping is: 533
# The remaining column names are:
# Unnamed: 0.1
# ctuid
# All others 2001
# Apartment, building that has fewer than five storeys 2001
# Apartment, building that has five or more storeys 2001
# Apartment, detached duplex 2001
# Average gross rent $ 2001
# Average household income $ 2001
# Average income $ 2001
# Average number of persons in private households 2001
# Average value of dwelling $ 2001
# Band housing 2001
# Bicycle 2001
# Born in province of residence 2001
# Born outside province of residence 2001
# Canadian citizenship 2001
# Car, truck, van, as driver 2001
# Car, truck, van, as passenger 2001
# Citizenship other than Canadian 2001
# College 2001
# Dwellings  2001
# Employment rate 2001
# Female, total 2001
# Females 2001
# Females with usual place of work or no fixed workplace address 2001
# GeoUID 2001
# Grades 9 to 13 2001
# Household income in 2000 of all private households 2001
# Households  2001
# ...
