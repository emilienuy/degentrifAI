# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/DataCleaning/Standardized_Census.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# example of apportioning data from source tracts to target tracts using an apportionment (i.e. crosswalk) table
import numpy as np

# the apportionment table
crosswalk_csv = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/CTs/ct_1996_2021.csv'

# the csv with source tract data to apportioned
data_csv = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Cleaned_Census_Data/1996_emilie_v1.csv'
# census_2006_v1 = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Cleaned_Census_Data/2006_emily_v2.csv'
# census_2006_v2 = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Cleaned_Census_Data/2006_emilie_v3.csv'

# %%
# JUST FOR 2006
import pandas as pd

census_2006_v2 = pd.read_csv(census_2006_v2)
census_2006_v1 = pd.read_csv(census_2006_v1)
print(census_2006_v1.head())
print(census_2006_v2.head())
# Out:
#       GeoUID  Population   Dwellings   Households   \
# 0  4620001.0         2498        1306         1243
# 1  4620002.0         2819        1399         1343
# 2  4620003.0         6407        2969         2884
# 3  4620004.0         3223        1627         1559
# 4  4620005.0         3188        1664         1601
#
#    Total population by sex and age groups - 100% data  Male, total  \
# 0                                             2500.0        1215.0
# 1                                             2820.0        1345.0
# 2                                             6405.0        3030.0
# 3                                             3225.0        1515.0
# 4                                             3185.0        1535.0
#
#    Total population 15 years and over by legal marital status - 100% data  \
# 0                                             2180.0
# 1                                             2385.0
# 2                                             5470.0
# 3                                             2850.0
# 4                                             2800.0
#
#    Never legally married (single)  Legally married (and not separated)  \
# 0                          1085.0                                590.0
# 1                          1140.0                                670.0
# 2                          2495.0                               1800.0
# 3                          1335.0                                775.0
# 4                          1380.0                                775.0
#
#    Separated, but still legally married  ...  MF 85+  Age 0 to 9  \
# 0                                  60.0  ...    20.0       205.0
# 1                                  60.0  ...    35.0       250.0
# 2                                 145.0  ...    85.0       585.0
# 3                                  85.0  ...    80.0       225.0
# 4                                  80.0  ...    30.0       245.0
#
#    Age 10 to 19  Age 20 to 29  Age 30 to 39  Age 40 to 49  Age 50 to 59  \
# 0         240.0         325.0         345.0         480.0         380.0
# 1         340.0         375.0         395.0         460.0         375.0
# 2         715.0         860.0         785.0        1090.0        1010.0
# 3         335.0         430.0         375.0         555.0         510.0
# 4         310.0         400.0         430.0         580.0         515.0
#
#    Age 60+  Owner-occupied private non-farm, non-reserve dwellings 2006  \
# 0    520.0                                             525.00
# 1    620.0                                             555.00
# 2   1375.0                                            1230.00
# 3    785.0                                             615.00
# 4    725.0                                             535.00
#
#    Tenant-occupied private non-farm, non-reserve dwellings 2006
# 0                                             720.00
# 1                                             785.00
# 2                                            1655.00
# 3                                             940.00
# 4                                            1060.00
#
# [5 rows x 120 columns]
#    Unnamed: 0     GeoUID  \
# 0           0  4620001.0
# 1           1  4620002.0
# 2           2  4620003.0
# 3           3  4620004.0
# 4           4  4620005.0
#
#   Total employed labour force 15 years and over with usual place of work or no fixed workplace address by mode of transportation - 20% sample data  \
# 0                                            1210.00
# 1                                            1310.00
# 2                                            3150.00
# 3                                            1520.00
# 4                                            1485.00
#
#    Walked Bicycle Motorcycle Taxicab Other method Car, truck, van, as driver  \
# 0   40.00    0.00       0.00    0.00        10.00                     750.00
# 1   80.00   10.00       0.00    0.00         0.00                     710.00
# 2  190.00   10.00       0.00   10.00         0.00                    1870.00
# 3  105.00   40.00       0.00   10.00        10.00                     750.00
# 4   35.00   35.00       0.00    0.00         0.00                     935.00
#
#   Car, truck, van, as passenger Public transit
# 0                         50.00         360.00
# 1                         10.00         505.00
# 2                        165.00         905.00
# 3                         65.00         550.00
# 4                         70.00         400.00

# %%
census_2006_v2.drop(['Unnamed: 0'], axis=1, inplace=True)

print(census_2006_v1.head())
print(census_2006_v2.head())
# Out:
#       GeoUID  Population   Dwellings   Households   \
# 0  4620001.0         2498        1306         1243
# 1  4620002.0         2819        1399         1343
# 2  4620003.0         6407        2969         2884
# 3  4620004.0         3223        1627         1559
# 4  4620005.0         3188        1664         1601
#
#    Total population by sex and age groups - 100% data  Male, total  \
# 0                                             2500.0        1215.0
# 1                                             2820.0        1345.0
# 2                                             6405.0        3030.0
# 3                                             3225.0        1515.0
# 4                                             3185.0        1535.0
#
#    Total population 15 years and over by legal marital status - 100% data  \
# 0                                             2180.0
# 1                                             2385.0
# 2                                             5470.0
# 3                                             2850.0
# 4                                             2800.0
#
#    Never legally married (single)  Legally married (and not separated)  \
# 0                          1085.0                                590.0
# 1                          1140.0                                670.0
# 2                          2495.0                               1800.0
# 3                          1335.0                                775.0
# 4                          1380.0                                775.0
#
#    Separated, but still legally married  ...  MF 85+  Age 0 to 9  \
# 0                                  60.0  ...    20.0       205.0
# 1                                  60.0  ...    35.0       250.0
# 2                                 145.0  ...    85.0       585.0
# 3                                  85.0  ...    80.0       225.0
# 4                                  80.0  ...    30.0       245.0
#
#    Age 10 to 19  Age 20 to 29  Age 30 to 39  Age 40 to 49  Age 50 to 59  \
# 0         240.0         325.0         345.0         480.0         380.0
# 1         340.0         375.0         395.0         460.0         375.0
# 2         715.0         860.0         785.0        1090.0        1010.0
# 3         335.0         430.0         375.0         555.0         510.0
# 4         310.0         400.0         430.0         580.0         515.0
#
#    Age 60+  Owner-occupied private non-farm, non-reserve dwellings 2006  \
# 0    520.0                                             525.00
# 1    620.0                                             555.00
# 2   1375.0                                            1230.00
# 3    785.0                                             615.00
# 4    725.0                                             535.00
#
#    Tenant-occupied private non-farm, non-reserve dwellings 2006
# 0                                             720.00
# 1                                             785.00
# 2                                            1655.00
# 3                                             940.00
# 4                                            1060.00
#
# [5 rows x 120 columns]
#       GeoUID  \
# 0  4620001.0
# 1  4620002.0
# 2  4620003.0
# 3  4620004.0
# 4  4620005.0
#
#   Total employed labour force 15 years and over with usual place of work or no fixed workplace address by mode of transportation - 20% sample data  \
# 0                                            1210.00
# 1                                            1310.00
# 2                                            3150.00
# 3                                            1520.00
# 4                                            1485.00
#
#    Walked Bicycle Motorcycle Taxicab Other method Car, truck, van, as driver  \
# 0   40.00    0.00       0.00    0.00        10.00                     750.00
# 1   80.00   10.00       0.00    0.00         0.00                     710.00
# 2  190.00   10.00       0.00   10.00         0.00                    1870.00
# 3  105.00   40.00       0.00   10.00        10.00                     750.00
# 4   35.00   35.00       0.00    0.00         0.00                     935.00
#
#   Car, truck, van, as passenger Public transit
# 0                         50.00         360.00
# 1                         10.00         505.00
# 2                        165.00         905.00
# 3                         65.00         550.00
# 4                         70.00         400.00

# %%
# Merge the dataframes on the common columns
df = pd.merge(census_2006_v1, census_2006_v2, on='GeoUID', how='inner')

# Display the merged dataframe
print(df)
# Out:
#         GeoUID  Population   Dwellings   Households   \
# 0    4620001.0         2498        1306         1243
# 1    4620002.0         2819        1399         1343
# 2    4620003.0         6407        2969         2884
# 3    4620004.0         3223        1627         1559
# 4    4620005.0         3188        1664         1601
# ..         ...          ...         ...          ...
# 855  4621001.0         3129        1161         1131
# 856  4621002.0         5243        2162         2114
# 857  4621003.0         6346        2407         2340
# 858  4621004.0         3764        1509         1475
# 859  4621005.0         5251        2267         2130
#
#      Total population by sex and age groups - 100% data  Male, total  \
# 0                                               2500.0        1215.0
# 1                                               2820.0        1345.0
# 2                                               6405.0        3030.0
# 3                                               3225.0        1515.0
# 4                                               3185.0        1535.0
# ..                                                 ...           ...
# 855                                             3130.0        1650.0
# 856                                             5245.0        2640.0
# 857                                             6345.0        3110.0
# 858                                             3765.0        1895.0
# 859                                             5255.0        2625.0
#
#      Total population 15 years and over by legal marital status - 100% data  \
# 0                                               2180.0
# 1                                               2385.0
# 2                                               5470.0
# 3                                               2850.0
# 4                                               2800.0
# ..                                                 ...
# 855                                             2460.0
# 856                                             4320.0
# 857                                             4955.0
# 858                                             2970.0
# 859                                             4235.0
#
#      Never legally married (single)  Legally married (and not separated)  \
# 0                            1085.0                                590.0
# 1                            1140.0                                670.0
# 2                            2495.0                               1800.0
# 3                            1335.0                                775.0
# 4                            1380.0                                775.0
# ..                              ...                                  ...
# 855                          1215.0                                890.0
# 856                          1920.0                               1695.0
# 857                          2135.0                               1945.0
# 858                          1370.0                               1025.0
# 859                          1870.0                               1600.0
#
#      Separated, but still legally married  ...  \
# 0                                    60.0  ...
# 1                                    60.0  ...
# 2                                   145.0  ...
# 3                                    85.0  ...
# 4                                    80.0  ...
# ..                                    ...  ...
# 855                                  20.0  ...
# 856                                  70.0  ...
# 857                                  75.0  ...
# 858                                  70.0  ...
# 859                                  85.0  ...
#
#      Tenant-occupied private non-farm, non-reserve dwellings 2006  \
# 0                                               720.00
# 1                                               785.00
# 2                                              1655.00
# 3                                               940.00
# 4                                              1060.00
# ..                                                 ...
# 855                                             100.00
# 856                                             205.00
# 857                                             135.00
# 858                                             230.00
# 859                                             200.00
#
#      Total employed labour force 15 years and over with usual place of work or no fixed workplace address by mode of transportation - 20% sample data  \
# 0                                              1210.00
# 1                                              1310.00
# 2                                              3150.00
# 3                                              1520.00
# 4                                              1485.00
# ..                                                 ...
# 855                                            1480.00
# 856                                            2715.00
# 857                                            3345.00
# 858                                            1935.00
# 859                                            2695.00
#
#      Walked  Bicycle  Motorcycle  Taxicab  Other method  \
# 0     40.00     0.00        0.00     0.00         10.00
# 1     80.00    10.00        0.00     0.00          0.00
# 2    190.00    10.00        0.00    10.00          0.00
# 3    105.00    40.00        0.00    10.00         10.00
# 4     35.00    35.00        0.00     0.00          0.00
# ..      ...      ...         ...      ...           ...
# 855   25.00    10.00        0.00     0.00         20.00
# 856  105.00    30.00        0.00     0.00         15.00
# 857   80.00     0.00        0.00     0.00         10.00
# 858  125.00    20.00        0.00     0.00          0.00
# 859   40.00    15.00        0.00     0.00         15.00
#
#      Car, truck, van, as driver  Car, truck, van, as passenger  Public transit
# 0                        750.00                          50.00          360.00
# 1                        710.00                          10.00          505.00
# 2                       1870.00                         165.00          905.00
# 3                        750.00                          65.00          550.00
# 4                        935.00                          70.00          400.00
# ..                          ...                            ...             ...
# 855                     1365.00                          50.00           10.00
# 856                     2325.00                         115.00          115.00
# 857                     3010.00                         185.00           55.00
# 858                     1715.00                          70.00           10.00
# 859                     2515.00                          85.00           25.00
#
# [860 rows x 129 columns]

# %%
import pprint
pprint.pprint(list(df.columns))
# Out:
# ['GeoUID',
#  'Population ',
#  'Dwellings ',
#  'Households ',
#  'Total population by sex and age groups - 100% data',
#  'Male, total',
#  'Total population 15 years and over by legal marital status - 100% data',
#  'Never legally married (single)',
#  'Legally married (and not separated)',
#  'Separated, but still legally married',
#  'Divorced',
#  'Widowed',
#  'Total number of census families in private households - 20% sample data',
#  'Total number of occupied private dwellings by structural type of dwelling - '
#  '100% data',
#  'Single-detached house',
#  'Semi-detached house',
#  'Row house',
#  'Apartment, duplex',
#  'Apartment, building that has five or more storeys',
#  'Apartment, building that has fewer than five storeys',
#  'Other single-attached house',
#  'Movable dwelling',
#  'Total number of private households by household size - 100% data',
#  'Number of persons in private households',
#  'Average number of persons in private households',
#  'Total number of private households by household type - 20% sample data',
#  'One-family households',
#  'Multiple-family households',
#  'Non-family households',
#  'Total number of occupied private dwellings by housing tenure - 20% sample '
#  'data',
#  'Owned',
#  'Rented',
#  'Band housing',
#  'Total number of occupied private dwellings by condition of dwelling - 20% '
#  'sample data',
#  'Regular maintenance only',
#  'Minor repairs',
#  'Major repairs',
#  'Total number of occupied private dwellings by period of construction - 20% '
#  'sample data',
#  'Period of construction, before 1946',
#  'Period of construction, 1946 to 1960',
#  'Period of construction, 1961 to 1970',
#  'Period of construction, 1971 to 1980',
#  'Period of construction, 1981 to 1985',
#  'Period of construction, 1986 to 1990',
#  'Period of construction, 1991 to 1995',
#  'Period of construction, 1996 to 2000',
#  'Period of construction, 2001 to 2006',
#  'Total - Mobility status 1 year ago - 20% sample data',
#  'Non-movers',
#  'Movers',
#  'Non-migrants',
#  'Migrants',
#  'Total population by citizenship - 20% sample data',
#  'Canadian citizens',
#  'Not Canadian citizens',
#  'Total population 15 years and over by labour force activity - 20% sample '
#  'data',
#  'Participation rate',
#  'Employment rate',
#  'Unemployment rate',
#  'Total population 15 to 24 years by highest certificate, diploma or degree - '
#  '20% sample data',
#  'No certificate, diploma or degree',
#  'Certificate, diploma or degree',
#  'High school certificate or equivalent',
#  'Apprenticeship or trades certificate or diploma',
#  'College, CEGEP or other non-university certificate or diploma',
#  'University certificate, diploma or degree',
#  'University certificate or diploma below bachelor level',
#  'University certificate or degree',
#  "Bachelor's degree",
#  'University certificate or diploma above bachelor level',
#  'Total population 25 to 64 years by highest certificate, diploma or degree - '
#  '20% sample data',
#  'Total population 65 years and over by highest certificate, diploma or degree '
#  '- 20% sample data',
#  'Total population 25 to 64 years with postsecondary qualification by location '
#  'of study - 20% sample data',
#  'Inside Canada',
#  'Quebec',
#  'Outside Canada',
#  'Total population by visible minority groups - 20% sample data',
#  'Total visible minority population',
#  'Not a visible minority',
#  'Household income in 2005 of private households - 20% sample data',
#  'Median household income $',
#  'After-tax income in 2005 of private households - 20% sample data',
#  'Average household income $',
#  'Median after-tax household income $',
#  'Average after-tax household income $',
#  'Average gross rent $',
#  'Total number of occupied private dwellings - 20% sample data',
#  'Average value of dwelling $',
#  'Tenant one-family households without additional persons in non-farm, '
#  'non-reserve private dwellings occupied by usual residents',
#  'Owner one-family households without additional persons in non-farm, '
#  'non-reserve private dwellings occupied by usual residents',
#  'MF 85+',
#  'Age 0 to 9',
#  'Age 10 to 19',
#  'Age 20 to 29',
#  'Age 30 to 39',
#  'Age 40 to 49',
#  'Age 50 to 59',
#  'Age 60+',
#  'Owner-occupied private non-farm, non-reserve dwellings',
#  'Tenant-occupied private non-farm, non-reserve dwellings',
#  'Total employed labour force 15 years and over with usual place of work or no '
#  'fixed workplace address by mode of transportation - 20% sample data',
#  'Walked',
#  'Bicycle',
#  'Motorcycle',
#  'Taxicab',
#  'Other method',
#  'Car, truck, van, as driver',
#  'Car, truck, van, as passenger',
#  'Public transit']

# %%
# only for 2006
# Remove " 2006" from column names
df = df.rename(columns={
    'Owner-occupied private non-farm, non-reserve dwellings 2006': 'Owner-occupied private non-farm, non-reserve dwellings',
    'Tenant-occupied private non-farm, non-reserve dwellings 2006': 'Tenant-occupied private non-farm, non-reserve dwellings'
})
pprint.pprint(list(df.columns))
# Out:
# ['GeoUID',
#  'Population ',
#  'Dwellings ',
#  'Households ',
#  'Total population by sex and age groups - 100% data',
#  'Male, total',
#  'Total population 15 years and over by legal marital status - 100% data',
#  'Never legally married (single)',
#  'Legally married (and not separated)',
#  'Separated, but still legally married',
#  'Divorced',
#  'Widowed',
#  'Total number of census families in private households - 20% sample data',
#  'Total number of occupied private dwellings by structural type of dwelling - '
#  '100% data',
#  'Single-detached house',
#  'Semi-detached house',
#  'Row house',
#  'Apartment, duplex',
#  'Apartment, building that has five or more storeys',
#  'Apartment, building that has fewer than five storeys',
#  'Other single-attached house',
#  'Movable dwelling',
#  'Total number of private households by household size - 100% data',
#  'Number of persons in private households',
#  'Average number of persons in private households',
#  'Total number of private households by household type - 20% sample data',
#  'One-family households',
#  'Multiple-family households',
#  'Non-family households',
#  'Total number of occupied private dwellings by housing tenure - 20% sample '
#  'data',
#  'Owned',
#  'Rented',
#  'Band housing',
#  'Total number of occupied private dwellings by condition of dwelling - 20% '
#  'sample data',
#  'Regular maintenance only',
#  'Minor repairs',
#  'Major repairs',
#  'Total number of occupied private dwellings by period of construction - 20% '
#  'sample data',
#  'Period of construction, before 1946',
#  'Period of construction, 1946 to 1960',
#  'Period of construction, 1961 to 1970',
#  'Period of construction, 1971 to 1980',
#  'Period of construction, 1981 to 1985',
#  'Period of construction, 1986 to 1990',
#  'Period of construction, 1991 to 1995',
#  'Period of construction, 1996 to 2000',
#  'Period of construction, 2001 to 2006',
#  'Total - Mobility status 1 year ago - 20% sample data',
#  'Non-movers',
#  'Movers',
#  'Non-migrants',
#  'Migrants',
#  'Total population by citizenship - 20% sample data',
#  'Canadian citizens',
#  'Not Canadian citizens',
#  'Total population 15 years and over by labour force activity - 20% sample '
#  'data',
#  'Participation rate',
#  'Employment rate',
#  'Unemployment rate',
#  'Total population 15 to 24 years by highest certificate, diploma or degree - '
#  '20% sample data',
#  'No certificate, diploma or degree',
#  'Certificate, diploma or degree',
#  'High school certificate or equivalent',
#  'Apprenticeship or trades certificate or diploma',
#  'College, CEGEP or other non-university certificate or diploma',
#  'University certificate, diploma or degree',
#  'University certificate or diploma below bachelor level',
#  'University certificate or degree',
#  "Bachelor's degree",
#  'University certificate or diploma above bachelor level',
#  'Total population 25 to 64 years by highest certificate, diploma or degree - '
#  '20% sample data',
#  'No certificate, diploma or degree.1',
#  'Certificate, diploma or degree.1',
#  'High school certificate or equivalent.1',
#  'Apprenticeship or trades certificate or diploma.1',
#  'College, CEGEP or other non-university certificate or diploma.1',
#  'University certificate, diploma or degree.1',
#  'University certificate or diploma below bachelor level.1',
#  "Bachelor's degree.1",
#  'University certificate or diploma above bachelor level.1',
#  'Total population 65 years and over by highest certificate, diploma or degree '
#  '- 20% sample data',
#  'No certificate, diploma or degree.2',
#  'Certificate, diploma or degree.2',
#  'High school certificate or equivalent.2',
#  'Apprenticeship or trades certificate or diploma.2',
#  'College, CEGEP or other non-university certificate or diploma.2',
#  'University certificate, diploma or degree.2',
#  'University certificate or diploma below bachelor level.2',
#  'University certificate or degree.1',
#  "Bachelor's degree.2",
#  'University certificate or diploma above bachelor level.2',
#  'Total population 25 to 64 years with postsecondary qualification by location '
#  'of study - 20% sample data',
#  'Inside Canada',
#  'Quebec',
#  'Outside Canada',
#  'Total population by visible minority groups - 20% sample data',
#  'Total visible minority population',
#  'Not a visible minority',
#  'Household income in 2005 of private households - 20% sample data',
#  'Median household income $',
#  'After-tax income in 2005 of private households - 20% sample data',
#  'Average household income $',
#  'Median after-tax household income $',
#  'Average after-tax household income $',
#  'Average gross rent $',
#  'Total number of occupied private dwellings - 20% sample data',
#  'Average value of dwelling $',
#  'Tenant one-family households without additional persons in non-farm, '
#  'non-reserve private dwellings occupied by usual residents',
#  'Average gross rent $.1',
#  'Owner one-family households without additional persons in non-farm, '
#  'non-reserve private dwellings occupied by usual residents',
#  'MF 85+',
#  'Age 0 to 9',
#  'Age 10 to 19',
#  'Age 20 to 29',
#  'Age 30 to 39',
#  'Age 40 to 49',
#  'Age 50 to 59',
#  'Age 60+',
#  'Owner-occupied private non-farm, non-reserve dwellings',
#  'Tenant-occupied private non-farm, non-reserve dwellings',
#  'Total employed labour force 15 years and over with usual place of work or no '
#  'fixed workplace address by mode of transportation - 20% sample data',
#  'Walked',
#  'Bicycle',
#  'Motorcycle',
#  'Taxicab',
#  'Other method',
#  'Car, truck, van, as driver',
#  'Car, truck, van, as passenger',
#  'Public transit']

# %%
import pandas as pd

# read in the data
df = pd.read_csv(data_csv) # COMMENT IF 2006

# read in crosswalk table
cw = pd.read_csv(crosswalk_csv)

df.drop(['Unnamed: 0'], axis=1, inplace=True)

import pprint
pprint.pprint(list(df.columns))
# Out:
# ['GeoUID',
#  'Median household income $',
#  'Owned',
#  'Average value of dwelling $',
#  'Rented',
#  'Average gross rent $',
#  'Total population 15 years and over by highest level of schooling',
#  "With bachelor's degree or higher"]

# %%
# for 2006 only
# bucket items
column_mapping = {}
for col in df.columns:
    if '.' in col:
        base_name = col.split('.')[0]
        if base_name not in column_mapping:
            column_mapping[base_name] = []
        column_mapping[base_name].append(col)

# Sum the columns with the same base name
for base_name, columns in column_mapping.items():
    df[base_name] = df[columns].sum(axis=1)
    df.drop(columns=columns, inplace=True)

pprint.pprint(list(df.columns))
# Out:
# ['GeoUID',
#  'Population ',
#  'Dwellings ',
#  'Households ',
#  'Total population by sex and age groups - 100% data',
#  'Male, total',
#  'Total population 15 years and over by legal marital status - 100% data',
#  'Never legally married (single)',
#  'Legally married (and not separated)',
#  'Separated, but still legally married',
#  'Divorced',
#  'Widowed',
#  'Total number of census families in private households - 20% sample data',
#  'Total number of occupied private dwellings by structural type of dwelling - '
#  '100% data',
#  'Single-detached house',
#  'Semi-detached house',
#  'Row house',
#  'Apartment, duplex',
#  'Apartment, building that has five or more storeys',
#  'Apartment, building that has fewer than five storeys',
#  'Other single-attached house',
#  'Movable dwelling',
#  'Total number of private households by household size - 100% data',
#  'Number of persons in private households',
#  'Average number of persons in private households',
#  'Total number of private households by household type - 20% sample data',
#  'One-family households',
#  'Multiple-family households',
#  'Non-family households',
#  'Total number of occupied private dwellings by housing tenure - 20% sample '
#  'data',
#  'Owned',
#  'Rented',
#  'Band housing',
#  'Total number of occupied private dwellings by condition of dwelling - 20% '
#  'sample data',
#  'Regular maintenance only',
#  'Minor repairs',
#  'Major repairs',
#  'Total number of occupied private dwellings by period of construction - 20% '
#  'sample data',
#  'Period of construction, before 1946',
#  'Period of construction, 1946 to 1960',
#  'Period of construction, 1961 to 1970',
#  'Period of construction, 1971 to 1980',
#  'Period of construction, 1981 to 1985',
#  'Period of construction, 1986 to 1990',
#  'Period of construction, 1991 to 1995',
#  'Period of construction, 1996 to 2000',
#  'Period of construction, 2001 to 2006',
#  'Total - Mobility status 1 year ago - 20% sample data',
#  'Non-movers',
#  'Movers',
#  'Non-migrants',
#  'Migrants',
#  'Total population by citizenship - 20% sample data',
#  'Canadian citizens',
#  'Not Canadian citizens',
#  'Total population 15 years and over by labour force activity - 20% sample '
#  'data',
#  'Participation rate',
#  'Employment rate',
#  'Unemployment rate',
#  'Total population 15 to 24 years by highest certificate, diploma or degree - '
#  '20% sample data',
#  'No certificate, diploma or degree',
#  'Certificate, diploma or degree',
#  'High school certificate or equivalent',
#  'Apprenticeship or trades certificate or diploma',
#  'College, CEGEP or other non-university certificate or diploma',
#  'University certificate, diploma or degree',
#  'University certificate or diploma below bachelor level',
#  'University certificate or degree',
#  "Bachelor's degree",
#  'University certificate or diploma above bachelor level',
#  'Total population 25 to 64 years by highest certificate, diploma or degree - '
#  '20% sample data',
#  'Total population 65 years and over by highest certificate, diploma or degree '
#  '- 20% sample data',
#  'Total population 25 to 64 years with postsecondary qualification by location '
#  'of study - 20% sample data',
#  'Inside Canada',
#  'Quebec',
#  'Outside Canada',
#  'Total population by visible minority groups - 20% sample data',
#  'Total visible minority population',
#  'Not a visible minority',
#  'Household income in 2005 of private households - 20% sample data',
#  'Median household income $',
#  'After-tax income in 2005 of private households - 20% sample data',
#  'Average household income $',
#  'Median after-tax household income $',
#  'Average after-tax household income $',
#  'Average gross rent $',
#  'Total number of occupied private dwellings - 20% sample data',
#  'Average value of dwelling $',
#  'Tenant one-family households without additional persons in non-farm, '
#  'non-reserve private dwellings occupied by usual residents',
#  'Owner one-family households without additional persons in non-farm, '
#  'non-reserve private dwellings occupied by usual residents',
#  'MF 85+',
#  'Age 0 to 9',
#  'Age 10 to 19',
#  'Age 20 to 29',
#  'Age 30 to 39',
#  'Age 40 to 49',
#  'Age 50 to 59',
#  'Age 60+',
#  'Owner-occupied private non-farm, non-reserve dwellings',
#  'Tenant-occupied private non-farm, non-reserve dwellings',
#  'Total employed labour force 15 years and over with usual place of work or no '
#  'fixed workplace address by mode of transportation - 20% sample data',
#  'Walked',
#  'Bicycle',
#  'Motorcycle',
#  'Taxicab',
#  'Other method',
#  'Car, truck, van, as driver',
#  'Car, truck, van, as passenger',
#  'Public transit']

# %% [markdown]
# # Choosing Columns

# %% [markdown]
# # 2016

# %%
# names of columns we want to apportion
fields = [
 'Population percentage change, 2011 to 2016 2016',
 'Total private dwellings 2016',
 'Private dwellings occupied by usual residents 2016',
 'Population density per square kilometre 2016',
 'Total - Age groups and average age of the population - 100% data 2016',
 '0 to 14 years 2016',
 '15 to 19 years 2016',
 '20 to 24 years 2016',
 '25 to 29 years 2016',
 '30 to 34 years 2016',
 '35 to 39 years 2016',
 '40 to 44 years 2016',
 '45 to 49 years 2016',
 '50 to 54 years 2016',
 '55 to 59 years 2016',
 '60 to 64 years 2016',
 '65 years and over 2016',
 'Average age of the population 2016',
 'Median age of the population 2016',
 'Total - Occupied private dwellings by structural type of dwelling - 100% '
 'data 2016',
 'Single-detached house 2016',
 'Apartment in a building that has five or more storeys 2016',
 'Semi-detached house 2016',
 'Row house 2016',
 'Apartment or flat in a duplex 2016',
 'Apartment in a building that has fewer than five storeys 2016',
 'Other single-attached house 2016',
 'Movable dwelling 2016',
 'Average household size 2016',
 'Total - Marital status for the population aged 15 years and over - 100% data '
 '2016',
 'Married or living common law 2016',
 'Not married and not living common law 2016',
 'Total - Income statistics in 2015 for private households by household size - '
 '100% data 2016',
 'Median total income of households in 2015 ($) 2016',
 'Median after-tax income of households in 2015 ($) 2016',
 'Prevalence of low income based on the Low-income measure, after tax (LIM-AT) '
 '(%) 2016',
 'Prevalence of low income based on the Low-income cut-offs, after tax '
 '(LICO-AT) (%) 2016',
 'Total - Citizenship for the population in private households - 25% sample '
 'data 2016',
 'Canadian citizens 2016',
 'Not Canadian citizens 2016',
 'Total - Immigrant status and period of immigration for the population in '
 'private households - 25% sample data 2016',
 'Non-immigrants 2016',
 'Immigrants 2016',
 'Non-permanent residents 2016',
 'Total - Visible minority for the population in private households - 25% '
 'sample data 2016',
 'Total visible minority population 2016',
 'Not a visible minority 2016',
 'Total - Private households by tenure - 25% sample data 2016',
 'Owner 2016',
 'Renter 2016',
 'Band housing 2016',
 'Total - Occupied private dwellings by condominium status - 25% sample data '
 '2016',
 'Condominium 2016',
 'Not condominium 2016',
 'Average number of rooms per dwelling 2016',
 'Total - Private households by housing suitability - 25% sample data 2016',
 'Suitable 2016',
 'Not suitable 2016',
 'Total - Occupied private dwellings by dwelling condition - 25% sample data '
 '2016',
 'Only regular maintenance or minor repairs needed 2016',
 'Major repairs needed 2016',
 'Total - Owner households in non-farm, non-reserve private dwellings - 25% '
 'sample data 2016',
 'Median monthly shelter costs for owned dwellings ($) 2016',
 'Average monthly shelter costs for owned dwellings ($) 2016',
 'Median value of dwellings ($) 2016',
 'Average value of dwellings ($) 2016',
 'Total - Tenant households in non-farm, non-reserve private dwellings - 25% '
 'sample data 2016',
 '% of tenant households in subsidized housing 2016',
 'Median monthly shelter costs for rented dwellings ($) 2016',
 'Total - Highest certificate, diploma or degree for the population aged 15 '
 'years and over in private households - 25% sample data 2016',
 'No certificate, diploma or degree 2016',
 'Secondary (high) school diploma or equivalency certificate 2016',
 'Postsecondary certificate, diploma or degree 2016',
 'Apprenticeship or trades certificate or diploma 2016',
 'College, CEGEP or other non-university certificate or diploma 2016',
 'University certificate or diploma below bachelor level 2016',
 'University certificate, diploma or degree at bachelor level or above 2016',
 'Total - Location of study compared with province or territory of residence '
 'with countries outside Canada for the population aged 15 years and over in '
 'private households - 25% sample data 2016',
 'Location of study inside Canada 2016',
 'Same as province or territory of residence 2016',
 'Different than province or territory of residence 2016',
 'Location of study outside Canada 2016',
 'Total - Population aged 15 years and over by Labour force status - 25% '
 'sample data 2016',
 'In the labour force 2016',
 'Not in the labour force 2016',
 'Total - Main mode of commuting for the employed labour force aged 15 years '
 'and over in private households with a usual place of work or no fixed '
 'workplace address - 25% sample data 2016',
 'Car, truck, van - as a driver 2016',
 'Car, truck, van - as a passenger 2016',
 'Public transit 2016',
 'Walked 2016',
 'Bicycle 2016',
 'Other method 2016',
 'Total - Commuting duration for the employed labour force aged 15 years and '
 'over in private households with a usual place of work or no fixed workplace '
 'address - 25% sample data 2016',
 'Less than 15 minutes 2016',
 '15 to 29 minutes 2016',
 '30 to 44 minutes 2016',
 '45 to 59 minutes 2016',
 '60 minutes and over 2016',
 'Total - Mobility status 1 year ago - 25% sample data 2016',
 'Non-movers 2016',
 'Movers 2016',
 'Population, 2016 2016']

# %% [markdown]
# # 2011

# %%
# names of columns we want to apportion
fields = [
 'Population in 2011 2011',
 '2006 to 2011 population change (%) 2011',
 'Total private dwellings 2011',
 'Private dwellings occupied by usual residents 2011',
 'Population density per square kilometre 2011',
 'Total population by age groups 2011',
 '0 to 4 years 2011',
 '5 to 9 years 2011',
 '10 to 14 years 2011',
 '15 to 19 years 2011',
 '20 to 24 years 2011',
 '25 to 29 years 2011',
 '30 to 34 years 2011',
 '35 to 39 years 2011',
 '40 to 44 years 2011',
 '45 to 49 years 2011',
 '50 to 54 years 2011',
 '55 to 59 years 2011',
 '60 to 64 years 2011',
 '65 to 69 years 2011',
 '70 to 74 years 2011',
 '75 to 79 years 2011',
 '80 to 84 years 2011',
 '85 years and over 2011',
 'Median age of the population 2011',
 'Total population 15 years and over by marital status 2011',
 'Married or living with a common-law partner 2011',
 'Not married and not living with a common-law partner 2011',
 'Total number of occupied private dwellings by structural type of dwelling '
 '2011',
 'Single-detached house 2011',
 'Apartment, building that has five or more storeys 2011',
 'Movable dwelling 2011',
 'Semi-detached house 2011',
 'Row house 2011',
 'Apartment, duplex 2011',
 'Apartment, building that has fewer than five storeys 2011',
 'Other single-attached house 2011',
 'Average number of persons in private households 2011',
 'Total population in private households by citizenship 2011',
 'Canadian citizens 2011',
 'Not Canadian citizens 2011',
 'Total population in private households by immigrant status and period of '
 'immigration 2011',
 'Non-immigrants 2011',
 'Immigrants 2011',
 'Non-permanent residents 2011',
 'Total population in private households by visible minority 2011',
 'Total visible minority population 2011',
 'Not a visible minority 2011',
 'Total - Mobility status 1 year ago 2011',
 'Non-movers 2011',
 'Movers 2011',
 'Total population aged 15 years and over by highest certificate, diploma or '
 'degree 2011',
 'No certificate, diploma or degree 2011',
 'High school diploma or equivalent 2011',
 'Postsecondary certificate, diploma or degree 2011',
 'Apprenticeship or trades certificate or diploma 2011',
 'College, CEGEP or other non-university certificate or diploma 2011',
 'University certificate or diploma below bachelor level 2011',
 'University certificate, diploma or degree at bachelor level or above 2011',
 'Total population aged 15 years and over by location of study compared with '
 'province or territory of residence 2011',
 'Location of study inside Canada 2011',
 'Same as province or territory of residence 2011',
 'Another province or territory 2011',
 'Location of study outside Canada 2011',
 'Total population aged 15 years and over by labour force status 2011',
 'In the labour force 2011',
 'Not in the labour force 2011',
 'Total employed population aged 15 years and over with a usual place of work '
 'or no fixed workplace address by mode of transportation 2011',
 'Car, truck or van - as a driver 2011',
 'Car, truck or van - as a passenger 2011',
 'Public transit 2011',
 'Walked 2011',
 'Bicycle 2011',
 'Other methods 2011',
 'Median commuting duration 2011',
 'Total number of occupied private dwellings by condition of dwelling 2011',
 'Only regular maintenance or minor repairs needed 2011',
 'Major repairs needed 2011',
 'Average number of rooms per dwelling 2011',
 'Total number of private households by tenure 2011',
 'Owner 2011',
 'Renter 2011',
 'Band housing 2011',
 'Total number of private households by condominium status 2011',
 'Part of a condominium development 2011',
 'Not part of a condominium development 2011',
 'Total number of private households by housing suitability 2011',
 'Suitable 2011',
 'Not suitable 2011',
 'Number of owner households in non-farm, non-reserve private dwellings 2011',
 'Median monthly shelter costs for owned dwellings ($) 2011',
 'Average monthly shelter costs for owned dwellings ($) 2011',
 'Median value of dwellings ($) 2011',
 'Average value of dwellings ($) 2011',
 'Number of tenant households in non-farm, non-reserve private dwellings 2011',
 '% of tenant households in subsidized housing 2011',
 'Median monthly shelter costs for rented dwellings ($) 2011',
 'Median after-tax income ($) 2011',
 'Median total income ($) 2011',
 'Household income in 2010 of private households 2011',
 'Prevalence of low income in 2010 based on after-tax low-income measure (%) '
 '2011']

# %% [markdown]
# # 2006

# %%
# names of columns we want to apportion
fields = [
 'Population ',
 'Dwellings ',
 'Households ',
 'Total population by sex and age groups - 100% data',
 'Male, total',
 'Total population 15 years and over by legal marital status - 100% data',
 'Never legally married (single)',
 'Legally married (and not separated)',
 'Separated, but still legally married',
 'Divorced',
 'Widowed',
 'Total number of census families in private households - 20% sample data',
 'Total number of occupied private dwellings by structural type of dwelling - '
 '100% data',
 'Single-detached house',
 'Semi-detached house',
 'Row house',
 'Apartment, duplex',
 'Apartment, building that has five or more storeys',
 'Apartment, building that has fewer than five storeys',
 'Other single-attached house',
 'Movable dwelling',
 'Total number of private households by household size - 100% data',
 'Number of persons in private households',
 'Average number of persons in private households',
 'Total number of private households by household type - 20% sample data',
 'One-family households',
 'Multiple-family households',
 'Non-family households',
 'Total number of occupied private dwellings by housing tenure - 20% sample '
 'data',
 'Owned',
 'Rented',
 'Band housing',
 'Total number of occupied private dwellings by condition of dwelling - 20% '
 'sample data',
 'Regular maintenance only',
 'Minor repairs',
 'Major repairs',
 'Total number of occupied private dwellings by period of construction - 20% '
 'sample data',
 'Period of construction, before 1946',
 'Period of construction, 1946 to 1960',
 'Period of construction, 1961 to 1970',
 'Period of construction, 1971 to 1980',
 'Period of construction, 1981 to 1985',
 'Period of construction, 1986 to 1990',
 'Period of construction, 1991 to 1995',
 'Period of construction, 1996 to 2000',
 'Period of construction, 2001 to 2006',
 'Total - Mobility status 1 year ago - 20% sample data',
 'Non-movers',
 'Movers',
 'Non-migrants',
 'Migrants',
 'Total population by citizenship - 20% sample data',
 'Canadian citizens',
 'Not Canadian citizens',
 'Total population 15 years and over by labour force activity - 20% sample '
 'data',
 'Participation rate',
 'Employment rate',
 'Unemployment rate',
 'Total population 15 to 24 years by highest certificate, diploma or degree - '
 '20% sample data',
 'No certificate, diploma or degree',
 'Certificate, diploma or degree',
 'High school certificate or equivalent',
 'Apprenticeship or trades certificate or diploma',
 'College, CEGEP or other non-university certificate or diploma',
 'University certificate, diploma or degree',
 'University certificate or diploma below bachelor level',
 'University certificate or degree',
 "Bachelor's degree",
 'University certificate or diploma above bachelor level',
 'Total population 25 to 64 years by highest certificate, diploma or degree - '
 '20% sample data',
 'Total population 65 years and over by highest certificate, diploma or degree '
 '- 20% sample data',
 'Total population 25 to 64 years with postsecondary qualification by location '
 'of study - 20% sample data',
 'Inside Canada',
 'Quebec',
 'Outside Canada',
 'Total population by visible minority groups - 20% sample data',
 'Total visible minority population',
 'Not a visible minority',
 'Household income in 2005 of private households - 20% sample data',
 'Median household income $',
 'After-tax income in 2005 of private households - 20% sample data',
 'Average household income $',
 'Median after-tax household income $',
 'Average after-tax household income $',
 'Average gross rent $',
 'Total number of occupied private dwellings - 20% sample data',
 'Average value of dwelling $',
 'Tenant one-family households without additional persons in non-farm, '
 'non-reserve private dwellings occupied by usual residents',
 'Owner one-family households without additional persons in non-farm, '
 'non-reserve private dwellings occupied by usual residents',
 'MF 85+',
 'Age 0 to 9',
 'Age 10 to 19',
 'Age 20 to 29',
 'Age 30 to 39',
 'Age 40 to 49',
 'Age 50 to 59',
 'Age 60+',
 'Owner-occupied private non-farm, non-reserve dwellings',
 'Tenant-occupied private non-farm, non-reserve dwellings',
 'Total employed labour force 15 years and over with usual place of work or no '
 'fixed workplace address by mode of transportation - 20% sample data',
 'Walked',
 'Bicycle',
 'Motorcycle',
 'Taxicab',
 'Other method',
 'Car, truck, van, as driver',
 'Car, truck, van, as passenger',
 'Public transit']

# %% [markdown]
# # 2001

# %%
# names of columns we want to apportion
fields = [
 'All others 2001',
 'Apartment, building that has fewer than five storeys 2001',
 'Apartment, building that has five or more storeys 2001',
 'Apartment, detached duplex 2001',
 'Average gross rent $ 2001',
 'Average household income $ 2001',
 'Average income $ 2001',
 'Average number of persons in private households 2001',
 'Average value of dwelling $ 2001',
 'Band housing 2001',
 'Bicycle 2001',
 'Born in province of residence 2001',
 'Born outside province of residence 2001',
 'Canadian citizenship 2001',
 'Car, truck, van, as driver 2001',
 'Car, truck, van, as passenger 2001',
 'Citizenship other than Canadian 2001',
 'College 2001',
 'Dwellings  2001',
 'Employment rate 2001',
 'Female, total 2001',
 'Females 2001',
 'Females with usual place of work or no fixed workplace address 2001',
 'GeoUID 2001',
 'Grades 9 to 13 2001',
 'Household income in 2000 of all private households 2001',
 'Households  2001',
 'Land area in square kilometres, 2001 2001',
 'Legally married (and not separated) 2001',
 'Less than grade 9 2001',
 'Low income 2001',
 'Major repairs 2001',
 'Male, total 2001',
 'Males 2001',
 'Males with usual place of work or no fixed workplace address 2001',
 'Median household income $ 2001',
 'Median income $ 2001',
 'Migrants 2001',
 'Minor repairs 2001',
 'Motorcycle 2001',
 'Movable dwelling 2001',
 'Movers 2001',
 'Never legally married (single) 2001',
 'Non-immigrant population 2001',
 'Non-migrants 2001',
 'Non-movers 2001',
 'Non-permanent residents 2001',
 'Number of persons in private households 2001',
 'Other 2001',
 'Other method 2001',
 'Other single-attached house 2001',
 'Owned 2001',
 'Owner households in non-farm, non-reserve private dwellings 2001',
 'Participation rate 2001',
 'Period of construction, 1946-1960 2001',
 'Period of construction, 1961-1970 2001',
 'Period of construction, 1971-1980 2001',
 'Period of construction, 1981-1990 2001',
 'Period of construction, 1991-1995 2001',
 'Period of construction, 1996-2001 2001',
 'Period of construction, before 1946 2001',
 'Population 15 years and over by labour force activity 2001',
 'Population percentage change, 1996-2001 2001',
 'Population, 2001 2001',
 'Public transit 2001',
 'Regular maintenance only 2001',
 'Rented 2001',
 'Row house 2001',
 'Semi-detached house 2001',
 'Single-detached house 2001',
 'Taxicab 2001',
 'Total - Economic families 2001',
 'Total - Population in private households 2001',
 'Total employed labour force 15 years and over by mode of transportation 2001',
 'Total employed labour force 15 years and over by place of work status 2001',
 'Total immigrants by selected places of birth 2001',
 'Total income in 2000 of population 15 years and over 2001',
 'Total number of occupied private dwellings by structural type of dwelling '
 '2001',
 'Total population 1 year and over by mobility status 1 year ago 2001',
 'Total population 15 years and over by legal marital status 2001',
 'Total population 20 years and over by highest level of schooling 2001',
 'Total population by citizenship 2001',
 'Total population by immigrant status and place of birth 2001',
 'Total population by sex and age groups 2001',
 'Total population of females with postsecondary qualifications by major field '
 'of study 2001',
 'Total population of males with postsecondary qualifications by major field '
 'of study 2001',
 'Total visible minority population 2001',
 'Trades certificate or diploma 2001',
 'Unemployment rate 2001',
 'University 2001',
 'Walked 2001',
 "With bachelor's degree or higher 2001",
 'With certificate or diploma 2001',
 'Without certificate or diploma 2001',
 'Without degree 2001',
 '0 to 19 years 2001',
 '20 to 29 years 2001',
 '30 to 39 years 2001',
 '40 to 49 years 2001',
 '50 to 59 years 2001',
 '60+ years 2001']

# %% [markdown]
# # 1996

# %%
fields = ['Median household income $',
 'Owned',
 'Average value of dwelling $',
 'Rented',
 'Average gross rent $',
 'Total population 15 years and over by highest level of schooling',
 "With bachelor's degree or higher"]

# %% [markdown]
# # Crosswalk

# %%
# the name of the field pertaining to the ctuid in data_csv
ctuidcol = "GeoUID"

# joining the two input tables
merge_cw_df = cw.merge(df, how = "right", left_on = "source_ctuid", right_on = ctuidcol)
# print(merge_cw_df.head())
# loop over each field, multiplying by the apportionment weight
output_fields = []
for f in fields:
    print(f)
    merge_cw_df[f] = np.asarray(merge_cw_df["w_pop"]) * np.asarray( pd.to_numeric(merge_cw_df[f], errors='coerce'))
    output_fields.append(f)

# group by the target census tracts, summing by the wanted fields
output_data = merge_cw_df.groupby(["target_ctuid"]).sum()
output_data = output_data[output_fields]
output_data = output_data.astype(int)
# Out:
# Median household income $
# Owned
# Average value of dwelling $
# Rented
# Average gross rent $
# Total population 15 years and over by highest level of schooling
# With bachelor's degree or higher

# %%
# for 2016
# output_data.columns = [str(col) + ' 2006' for col in output_data.columns]
# for 1996
output_data.columns = [str(col) + ' 1996' for col in output_data.columns]

# output file name
output_file_name = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/1996_census_standardized.csv'

# write to file
output_data.to_csv(output_file_name)
output_data.head()
# Out:
#               Median household income $ 1996  Owned 1996  \
# target_ctuid
# -1.0                                       0           0
#  4620001.0                             31045         405
#  4620002.0                             28694         500
#  4620003.0                             33312        1095
#  4620004.0                             28781         470
#
#               Average value of dwelling $ 1996  Rented 1996  \
# target_ctuid
# -1.0                                         0            0
#  4620001.0                              109385          690
#  4620002.0                              100160          765
#  4620003.0                              127379         1625
#  4620004.0                              114209         1015
#
#               Average gross rent $ 1996  \
# target_ctuid
# -1.0                                  0
#  4620001.0                          491
#  4620002.0                          487
#  4620003.0                          525
#  4620004.0                          519
#
#               Total population 15 years and over by highest level of schooling 1996  \
# target_ctuid
# -1.0                                                          0
#  4620001.0                                                 1990
#  4620002.0                                                 2360
#  4620003.0                                                 5405
#  4620004.0                                                 2640
#
#               With bachelor's degree or higher 1996
# target_ctuid
# -1.0                                              0
#  4620001.0                                      125
#  4620002.0                                       70
#  4620003.0                                      435
#  4620004.0                                      165
