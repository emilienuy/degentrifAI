# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/Standardized_Census.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2016

# %%
# example of apportioning data from source tracts to target tracts using an apportionment (i.e. crosswalk) table
import numpy as np

# the apportionment table
crosswalk_csv = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/CTs/ct_2016_2021.csv'

# the csv with source tract data to apportioned
data_csv = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Cleaned_Census_Data/2016_emilie_v1.csv'


# the name of the field pertaining to the ctuid in data_csv
ctuidcol = "ctuid"

# %%
import pandas as pd

# read in the data
df = pd.read_csv(data_csv)

# read in crosswalk table
cw = pd.read_csv(crosswalk_csv)

import pprint
pprint.pprint(list(df.columns))
# Out:
# ['Unnamed: 0',
#  'ctuid',
#  'Population percentage change, 2011 to 2016 2016',
#  'Total private dwellings 2016',
#  'Private dwellings occupied by usual residents 2016',
#  'Population density per square kilometre 2016',
#  'Total - Age groups and average age of the population - 100% data 2016',
#  '0 to 14 years 2016',
#  '15 to 19 years 2016',
#  '20 to 24 years 2016',
#  '25 to 29 years 2016',
#  '30 to 34 years 2016',
#  '35 to 39 years 2016',
#  '40 to 44 years 2016',
#  '45 to 49 years 2016',
#  '50 to 54 years 2016',
#  '55 to 59 years 2016',
#  '60 to 64 years 2016',
#  '65 years and over 2016',
#  'Average age of the population 2016',
#  'Median age of the population 2016',
#  'Total - Occupied private dwellings by structural type of dwelling - 100% '
#  'data 2016',
#  'Single-detached house 2016',
#  'Apartment in a building that has five or more storeys 2016',
#  'Semi-detached house 2016',
#  'Row house 2016',
#  'Apartment or flat in a duplex 2016',
# ...

# %% [markdown]
# # Choosing Columns

# %% [markdown]
# # 2016

# %%
# names of columns we want to apportion
fields = [
 'Population percentage change, 2011 to 2016 2016',
 'Total private dwellings 2016',
 'Private dwellings occupied by usual residents 2016',
 'Population density per square kilometre 2016',
 'Total - Age groups and average age of the population - 100% data 2016',
 '0 to 14 years 2016',
 '15 to 19 years 2016',
 '20 to 24 years 2016',
 '25 to 29 years 2016',
 '30 to 34 years 2016',
 '35 to 39 years 2016',
 '40 to 44 years 2016',
 '45 to 49 years 2016',
 '50 to 54 years 2016',
 '55 to 59 years 2016',
 '60 to 64 years 2016',
 '65 years and over 2016',
 'Average age of the population 2016',
 'Median age of the population 2016',
 'Total - Occupied private dwellings by structural type of dwelling - 100% data 2016',
 'Single-detached house 2016',
 'Apartment in a building that has five or more storeys 2016',
 'Semi-detached house 2016',
 'Row house 2016',
 'Apartment or flat in a duplex 2016',
 'Apartment in a building that has fewer than five storeys 2016',
 'Other single-attached house 2016',
 'Movable dwelling 2016',
 'Average household size 2016',
 'Total - Marital status for the population aged 15 years and over - 100% data 2016',
 'Married or living common law 2016',
 'Not married and not living common law 2016',
 'Median total income of households in 2015 ($) 2016',
 'Median after-tax income of households in 2015 ($) 2016',
 'Prevalence of low income based on the Low-income measure, after tax (LIM-AT) (%) 2016',
 'Prevalence of low income based on the Low-income cut-offs, after tax (LICO-AT) (%) 2016',
 'Total - Citizenship for the population in private households - 25% sample data 2016',
 'Canadian citizens 2016',
 'Not Canadian citizens 2016',
 'Total - Immigrant status and period of immigration for the population in private households - 25% sample data 2016',
 'Non-immigrants 2016',
 'Immigrants 2016',
 'Non-permanent residents 2016',
 'Total - Visible minority for the population in private households - 25% sample data 2016',
 'Total visible minority population 2016',
 'Not a visible minority 2016',
 'Total - Private households by tenure - 25% sample data 2016',
 'Owner 2016',
 'Renter 2016',
 'Band housing 2016',
 'Total - Occupied private dwellings by condominium status - 25% sample data 2016',
 'Condominium 2016',
 'Not condominium 2016',
 'Average number of rooms per dwelling 2016',
 'Total - Private households by housing suitability - 25% sample data 2016',
 'Suitable 2016',
 'Not suitable 2016',
 'Total - Occupied private dwellings by dwelling condition - 25% sample data 2016',
 'Only regular maintenance or minor repairs needed 2016',
 'Major repairs needed 2016',
 'Median monthly shelter costs for owned dwellings ($) 2016',
 'Average monthly shelter costs for owned dwellings ($) 2016',
 'Median value of dwellings ($) 2016',
 'Average value of dwellings ($) 2016',
 '% of tenant households in subsidized housing 2016',
 'Median monthly shelter costs for rented dwellings ($) 2016',
 'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data 2016',
 'No certificate, diploma or degree 2016',
 'Secondary (high) school diploma or equivalency certificate 2016',
 'Postsecondary certificate, diploma or degree 2016',
 'Apprenticeship or trades certificate or diploma 2016',
 'College, CEGEP or other non-university certificate or diploma 2016',
 'University certificate or diploma below bachelor level 2016',
 'University certificate, diploma or degree at bachelor level or above 2016',
 'Total - Location of study compared with province or territory of residence '
 'with countries outside Canada for the population aged 15 years and over in '
 'private households - 25% sample data 2016',
 'Location of study inside Canada 2016',
 'Same as province or territory of residence 2016',
 'Different than province or territory of residence 2016',
 'Location of study outside Canada 2016',
 'Total - Population aged 15 years and over by Labour force status - 25% sample data 2016',
 'In the labour force 2016',
 'Not in the labour force 2016',
 'Total - Main mode of commuting for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data 2016',
 'Car, truck, van - as a driver 2016',
 'Car, truck, van - as a passenger 2016',
 'Public transit 2016',
 'Walked 2016',
 'Bicycle 2016',
 'Other method 2016',
 'Total - Commuting duration for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data 2016',
 'Less than 15 minutes 2016',
 '15 to 29 minutes 2016',
 '30 to 44 minutes 2016',
 '45 to 59 minutes 2016',
 '60 minutes and over 2016',
 'Total - Mobility status 1 year ago - 25% sample data 2016',
 'Non-movers 2016',
 'Movers 2016',
 'Population, 2016 2016']

# %% [markdown]
# # 2021

# %%
# joining the two input tables
merge_cw_df = cw.merge(df, how = "inner", left_on = "source_ctuid", right_on = ctuidcol)
# print(merge_cw_df.head())
# loop over each field, multiplying by the apportionment weight
output_fields = []
for f in fields:
    print(f)
    merge_cw_df["w_" + f] = np.asarray(merge_cw_df["w_pop"]) * np.asarray( pd.to_numeric(merge_cw_df[f], errors='coerce'))
    output_fields.append("w_" + f)

# group by the target census tracts, summing by the wanted fields
output_data = merge_cw_df.groupby(["target_ctuid"]).sum()
output_data = output_data[output_fields]
output_data= output_data.astype(int)

output_data.rename(columns=lambda x: x.replace('w_', ''), inplace=True)
# Out:
# Population percentage change, 2011 to 2016 2016
# Total private dwellings 2016
# Private dwellings occupied by usual residents 2016
# Population density per square kilometre 2016
# Total - Age groups and average age of the population - 100% data 2016
# 0 to 14 years 2016
# 15 to 19 years 2016
# 20 to 24 years 2016
# 25 to 29 years 2016
# 30 to 34 years 2016
# 35 to 39 years 2016
# 40 to 44 years 2016
# 45 to 49 years 2016
# 50 to 54 years 2016
# 55 to 59 years 2016
# 60 to 64 years 2016
# 65 years and over 2016
# Average age of the population 2016
# Median age of the population 2016
# Total - Occupied private dwellings by structural type of dwelling - 100% data 2016
# Single-detached house 2016
# Apartment in a building that has five or more storeys 2016
# Semi-detached house 2016
# Row house 2016
# Apartment or flat in a duplex 2016
# Apartment in a building that has fewer than five storeys 2016
# Other single-attached house 2016
# Movable dwelling 2016
# ...

# %%
# output file name
output_file_name = '/content/drive/MyDrive/GentrificAItion/Montreal_data_from_census/Standardized_Census_Data/2016_census_standardized.csv'

# write to file
output_data.to_csv(output_file_name)
output_data.head()
# Out:
#               Population percentage change, 2011 to 2016 2016  \
# target_ctuid
# -1.0                                                        0
#  4620001.0                                                  1
#  4620002.0                                                 15
#  4620003.0                                                  2
#  4620004.0                                                 -2
#
#               Total private dwellings 2016  \
# target_ctuid
# -1.0                                     0
#  4620001.0                            1452
#  4620002.0                            1902
#  4620003.0                            3103
#  4620004.0                            1704
#
#               Private dwellings occupied by usual residents 2016  \
# target_ctuid
# -1.0                                                          0
#  4620001.0                                                 1328
#  4620002.0                                                 1762
# ...
