# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/degentrificAItion/blob/main/De_gentrificAItion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install stats-can
# Out:
# Collecting stats-can
#   Downloading stats_can-2.5.3-py3-none-any.whl (25 kB)
# Requirement already satisfied: h5py>=2.10 in /usr/local/lib/python3.10/dist-packages (from stats-can) (3.9.0)
# Requirement already satisfied: importlib-metadata>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from stats-can) (7.1.0)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from stats-can) (2.0.3)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from stats-can) (2.31.0)
# Requirement already satisfied: tables>=3.6 in /usr/local/lib/python3.10/dist-packages (from stats-can) (3.8.0)
# Requirement already satisfied: tqdm>=4.48 in /usr/local/lib/python3.10/dist-packages (from stats-can) (4.66.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py>=2.10->stats-can) (1.25.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.0.0->stats-can) (3.19.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->stats-can) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->stats-can) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->stats-can) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->stats-can) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->stats-can) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->stats-can) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->stats-can) (2024.6.2)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables>=3.6->stats-can) (3.0.10)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables>=3.6->stats-can) (2.10.0)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables>=3.6->stats-can) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tables>=3.6->stats-can) (24.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables>=3.6->stats-can) (9.0.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2~=2.0.0->tables>=3.6->stats-can) (1.0.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->stats-can) (1.16.0)
# Installing collected packages: stats-can
# Successfully installed stats-can-2.5.3

# %%
import pandas as pd
import csv

# with open("/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/2016_census.csv", mode='r') as file:
#     reader = csv.reader(file)
#     for i, row in enumerate(reader):
#       print(i)
#         # if 3585760 <= i <= 3585780:
#         #     print(i, row)


# specify rows to import
# specific_rows = [x for x in range(1406624, 3588460)]

# skip 3585766
df = pd.read_csv('/content/drive/MyDrive/Ai4Good Colabs (Emily Hong)/2016_census.csv', skiprows = lambda x: x not in specific_rows)

# skip 3585766

# %%
# identify variables you want to keep, ie housing etc and drop rest
# montreal = [1406624, 3588460]
# Out:
# 3585765

# %%
# add data from 2011 and 2021 census
